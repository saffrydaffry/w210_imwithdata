# %% [markdown]
# ## Global Giving API
#
# Global Giving Foundation is a non-profit that vets other non-profits and charities. The response only returns 10 results for each request.  While there are more entries, the "hasNext" value will be true.
#
# https://www.globalgiving.org/api

# %%
import boto3
import requests
import os

from configparser import ConfigParser
from collections import OrderedDict
from retrying import retry
from io import StringIO

ini_file = os.path.join(os.pardir, "config", "config.ini")

def get_ini_vals(ini_file, section):
    config = ConfigParser()
    config.read(ini_file)
    return config[section]
    
country = 'US'
keys = get_ini_vals(ini_file, "globalgiving.api")
print("Reading configs from from %s" % ini_file)
print(keys)
# Out:
# Reading configs from from ../config/config.ini
# <Section: globalgiving.api>

# %% [markdown]
# ### Projects API
#
# Tags of interest:
# ```
# <project>
#     <hasNext>true</hasNext>   # if there are more results
#     <activities>Energy healers have been researching the effects of metals and the elements on the health of the human body. CHI plans to hold workshops to train energy healers to utilize various metals and the elements in promoting healthier lifestyles.
#     </activities>
# ```
# (address/time info)
#
# ```
#         <approvedDate>2003-05-20T19:40:05-04:00</approvedDate>
#         <contactAddress>Creating Hope International</contactAddress>
#         <contactAddress2>P. O. Box 1058</contactAddress2>
#         <contactCity>Dearborn</contactCity>
#         <contactCountry>United States</contactCountry>
#         <contactPostal>48121</contactPostal>
#         <contactState>Michigan</contactState>
#         <contactUrl>http://www.creatinghope.org</contactUrl>
#         <country>United States</country>
#
#
#             <imagelink size="medium">
#                 <url>oaiwefjslc.jpg</url>
#             </imagelink>
#
# ```
# (organization-images)
#
# ```
#         <logoUrl>https://dpqe0zkrjo0ak.cloudfront.net/pfil/organ/254/orglogo.jpg</logoUrl>
#
# ```

# %%
url= "https://api.globalgiving.org/api/public/projectservice/countries/{country_}/projects".format(country_=country)
session = requests.session()
response = session.get(url, params={'api_key':'37466a9c-154d-4d82-aff8-7cb02a1bfbb1'})

# %%
response_text = response.text
print(response.text)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <projects numberFound="2428">
#     <hasNext>true</hasNext>
#     <nextProjectId>607</nextProjectId>
#     <project>
#         <active>false</active>
#         <activities>Energy healers have been researching the effects of metals and the elements on the health of the human body. CHI plans to hold workshops to train energy healers to utilize various metals and the elements in promoting healthier lifestyles.</activities>
#         <additionalDocumentation>https://www.globalgiving.org/pfil/16/projdoc.doc</additionalDocumentation>
#         <approvedDate>2003-05-20T19:40:05-04:00</approvedDate>
#         <contactAddress>Creating Hope International</contactAddress>
#         <contactAddress2>P. O. Box 1058</contactAddress2>
#         <contactCity>Dearborn</contactCity>
#         <contactCountry>United States</contactCountry>
#         <contactPostal>48121</contactPostal>
#         <contactState>Michigan</contactState>
#         <contactUrl>http://www.creatinghope.org</contactUrl>
#         <country>United States</country>
#         <funding>0.00</funding>
#         <goal>3300.00</goal>
#         <id>16</id>
#         <image id="0">
#             <imagelink size="small">
#                 <url>https://www.globalgiving.org/share/dfltpict.jpg</url>
#             </imagelink>
#             <imagelink size="thumbnail">
#                 <url>https://www.globalgiving.org/share/dfltpict.jpg</url>
#             </imagelink>
#             <imagelink size="medium">
#                 <url>https://www.globalgiving.org/share/dfltpict.jpg</url>
#             </imagelink>
#             <imagelink size="large">
#                 <url>https://www.globalgiving.org/share/dfltpict.jpg</url>
#             </imagelink>
#             <imagelink size="extraLarge">
#                 <url>https://www.globalgiving.org/share/dfltpict.jpg</url>
#             </imagelink>
#             <imagelink size="original">
#                 <url>https://www.globalgiving.org/share/dfltpict.jpg</url>
#             </imagelink>
#             <title>Improving Health by Complementary Health Practices</title>
#
#         <imageLink>https://www.globalgiving.org/share/dfltpict.jpg</imageLink>
#         <iso3166CountryCode>US</iso3166CountryCode>
#         <longTermImpact>In these workshops, participants will learn how to help themselves and others through energy healing.</longTermImpact>
#         <need>Americans today expect to live longer than ever before. Unfortunately, increases in life expectancy also mean that people cope with chronic and terminal illnesses for years and even decades. This situation has prompted interest in healing alternatives to complement allopathic medicine. In 2001, Creating Hope International (CHI) began supporting the work of energy healers who have helped and healed many people.</need>
#         <numberOfDonations>0</numberOfDonations>
#         <organization>
#             <activeProjects>7</activeProjects>
#             <addressLine1>Creating Hope International</addressLine1>
#             <addressLine2>PO Box 1058</addressLine2>
#             <city>Dearborn</city>
#             <countries>
#                 <country>
#                     <iso3166CountryCode>AF</iso3166CountryCode>
#                     <name>Afghanistan</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>IN</iso3166CountryCode>
#                     <name>India</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>NP</iso3166CountryCode>
#                     <name>Nepal</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>PK</iso3166CountryCode>
#                     <name>Pakistan</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>US</iso3166CountryCode>
#                     <name>United States</name>
#                 </country>
#             </countries>
#             <country>United States</country>
#             <ein>38-3288402</ein>
#             <id>254</id>
#             <iso3166CountryCode>US</iso3166CountryCode>
#             <logoUrl>https://dpqe0zkrjo0ak.cloudfront.net/pfil/organ/254/orglogo.jpg</logoUrl>
#             <mission>Creating Hope International (CHI) was founded with the vision of bringing hope to victims of war, political unrest, and natural disasters through programs designed to help them rebuild their lives for a brighter tomorrow. CHI's mission is to empower grassroots organizations that provide education, training, and health care to needy people. CHI supports organizations that respond to community needs on an individual level, foster community participation and utilize culturally sensitive education and training.</mission>
#             <name>Creating Hope International (CHI)</name>
#             <postal>48121</postal>
#             <state>Michigan</state>
#             <themes>
#                 <theme>
#                     <id>children</id>
#                     <name>Children</name>
#                 </theme>
#                 <theme>
#                     <id>democ</id>
#                     <name>Democracy and Governance</name>
#                 </theme>
#                 <theme>
#                     <id>disaster</id>
#                     <name>Disaster Recovery</name>
#                 </theme>
#                 <theme>
#                     <id>ecdev</id>
#                     <name>Economic Development</name>
#                 </theme>
#                 <theme>
#                     <id>edu</id>
#                     <name>Education</name>
#                 </theme>
#                 <theme>
#                     <id>env</id>
#                     <name>Environment</name>
#                 </theme>
#                 <theme>
#                     <id>gender</id>
#                     <name>Women and Girls</name>
#                 </theme>
#                 <theme>
#                     <id>health</id>
#                     <name>Health</name>
#                 </theme>
#                 <theme>
#                     <id>human</id>
#                     <name>Humanitarian Assistance</name>
#                 </theme>
#                 <theme>
#                     <id>rights</id>
#                     <name>Human Rights</name>
#                 </theme>
#                 <theme>
#                     <id>hunger</id>
#                     <name>Hunger</name>
#                 </theme>
#                 <theme>
#                     <id>art</id>
#                     <name>Arts and Culture</name>
#                 </theme>
#             </themes>
#             <totalProjects>140</totalProjects>
#             <url>http://www.creatinghope.org</url>
#         </organization>
#         <progressReportLink>https://www.globalgiving.org/projects/improving-health-by-complementary-health-practices/updates/</progressReportLink>
#         <projectLink>https://www.globalgiving.org/projects/improving-health-by-complementary-health-practices/</projectLink>
#         <region>North America</region>
#         <remaining>3300.00</remaining>
#         <status>retired</status>
#         <summary>Opening doors to better health through research and workshops on energy healing as a complementary alternative to allopathic medicine.</summary>
#         <themeName>Health</themeName>
#         <title>Improving Health by Complementary Health Practices</title>
#         <type>project</type>
#     </project>
#     <project>
#         <active>false</active>
#         <activities>To purchase and scan 100 books that have been requested by teachers and parents. Ten of these will be textbooks that will be proofread for perfect text accuracy. All 100 will be shared nationwide through the Bookshare.org online collection.</activities>
#         <additionalDocumentation>https://www.globalgiving.org/pfil/31/projdoc.doc</additionalDocumentation>
#         <approvedDate>2003-05-30T16:38:38-04:00</approvedDate>
#         <contactAddress>480 S. California Ave</contactAddress>
#         <contactAddress2>Suite 201</contactAddress2>
#         <contactCity>Palo Alto</contactCity>
#         <contactCountry>United States</contactCountry>
#         <contactName>James Fruchterman</contactName>
#         <contactPostal>94306</contactPostal>
#         <contactState>California</contactState>
#         <contactTitle>President and CEO</contactTitle>
#         <contactUrl>http://www.benetech.org</contactUrl>
#         <country>United States</country>
#         <funding>2420.00</funding>
#         <goal>5060.00</goal>
#         <id>31</id>
#         <image id="0">
#             <imagelink size="small">
#                 <url>https://www.globalgiving.org/pfil/31/pict_grid1.jpg</url>
#             </imagelink>
#             <imagelink size="thumbnail">
#                 <url>https://www.globalgiving.org/pfil/31/pict_thumbnail.jpg</url>
#             </imagelink>
#             <imagelink size="medium">
#                 <url>https://www.globalgiving.org/pfil/31/pict_med.jpg</url>
#             </imagelink>
#             <imagelink size="large">
#                 <url>https://www.globalgiving.org/pfil/31/pict_grid7.jpg</url>
#             </imagelink>
#             <imagelink size="extraLarge">
#                 <url>https://www.globalgiving.org/pfil/31/pict_large.jpg</url>
#             </imagelink>
#             <imagelink size="original">
#                 <url>https://www.globalgiving.org/pfil/31/pict_original.jpg</url>
#             </imagelink>
#             <title>Accessible Books for Students with Disabilities</title>
#
#         <imageGallerySize>1</imageGallerySize>
#         <imageLink>https://www.globalgiving.org/pfil/31/pict.jpg</imageLink>
#         <iso3166CountryCode>US</iso3166CountryCode>
#         <longTermImpact>This project will help to develop a core collection of K-12 books to serve students with disabilities.</longTermImpact>
#         <need>Fewer than 5% of books are produced in formats that are accessible to people who have visual or learning disabilities.  To read other books, more than three million US residents, including one million students, are forced to laboriously scan them into computers.  In particular, K-12 students need accessible textbooks and outside reading material.  Schools are legally required to offer textbooks in these formats, but access is often inadequate and little supplemental reading is made available.</need>
#         <numberOfDonations>23</numberOfDonations>
#         <organization>
#             <activeProjects>0</activeProjects>
#             <addressLine1>480 S. California Ave Suite 201</addressLine1>
#             <addressLine2></addressLine2>
#             <city>Palo Alto</city>
#             <countries>
#                 <country>
#                     <iso3166CountryCode>BD</iso3166CountryCode>
#                     <name>Bangladesh</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>GT</iso3166CountryCode>
#                     <name>Guatemala</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>IN</iso3166CountryCode>
#                     <name>India</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>US</iso3166CountryCode>
#                     <name>United States</name>
#                 </country>
#             </countries>
#             <country>United States</country>
#             <ein>77-0225904</ein>
#             <id>200</id>
#             <iso3166CountryCode>US</iso3166CountryCode>
#             <mission>Benetech is a Silicon Valley nonprofit that develops technology projects addressing major social problems in areas such as disability, human rights, literacy and education. Our predecessor nonprofit, Arkenstone, was founded in 1989 to provide reading tools for people with disabilities. It helped 35,000 visually impaired people in 60 countries to live and work independently before the sale of its business operations to a for-profit company in 2000, which led to the launch of Benetech.&#xD;
# </mission>
#             <name>Benetech</name>
#             <postal>94306</postal>
#             <state>CA</state>
#             <themes>
#                 <theme>
#                     <id>edu</id>
#                     <name>Education</name>
#                 </theme>
#                 <theme>
#                     <id>rights</id>
#                     <name>Human Rights</name>
#                 </theme>
#                 <theme>
#                     <id>tech</id>
#                     <name>Technology</name>
#                 </theme>
#             </themes>
#             <totalProjects>6</totalProjects>
#             <url>http://www.benetech.org</url>
#         </organization>
#         <progressReportLink>https://www.globalgiving.org/projects/students-with-disabilities/updates/</progressReportLink>
#         <projectLink>https://www.globalgiving.org/projects/students-with-disabilities/</projectLink>
#         <region>North America</region>
#         <remaining>2640.00</remaining>
#         <status>funded</status>
#         <summary>Adding more accessible textbooks and supplemental reading material for K-12 students with visual and learning disabilities to the Bookshare.org online collection.</summary>
#         <themeName>Education</themeName>
#         <title>Accessible Books for Students with Disabilities</title>
#         <type>project</type>
#     </project>
#     <project>
#         <active>false</active>
#         <activities>CAT hopes to create classrooms where students participate more actively in learning by improve instruction for 750 additional students through working with 25 more teachers in 2004.</activities>
#         <additionalDocumentation>https://www.globalgiving.org/pfil/51/projdoc.doc</additionalDocumentation>
#         <approvedDate>2003-06-30T14:03:32-04:00</approvedDate>
#         <contactAddress>1421 22nd St., NW</contactAddress>
#         <contactCity>Washington, D.C.</contactCity>
#         <contactCountry>United States</contactCountry>
#         <contactPostal>20037</contactPostal>
#         <contactState></contactState>
#         <contactUrl>http://www.artistryinteaching.org</contactUrl>
#         <country>United States</country>
#         <funding>0.00</funding>
#         <goal>22000.00</goal>
#         <id>51</id>
#         <image id="0">
#             <imagelink size="small">
#                 <url>https://www.globalgiving.org/pfil/51/pict_grid1.jpg</url>
#             </imagelink>
#             <imagelink size="thumbnail">
#                 <url>https://www.globalgiving.org/pfil/51/pict_thumbnail.jpg</url>
#             </imagelink>
#             <imagelink size="medium">
#                 <url>https://www.globalgiving.org/pfil/51/pict_med.jpg</url>
#             </imagelink>
#             <imagelink size="large">
#                 <url>https://www.globalgiving.org/pfil/51/pict_grid7.jpg</url>
#             </imagelink>
#             <imagelink size="extraLarge">
#                 <url>https://www.globalgiving.org/pfil/51/pict_large.jpg</url>
#             </imagelink>
#             <imagelink size="original">
#                 <url>https://www.globalgiving.org/pfil/51/pict_original.jpg</url>
#             </imagelink>
#             <title>Workshop in the Art of Teaching</title>
#
#         <imageGallerySize>1</imageGallerySize>
#         <imageLink>https://www.globalgiving.org/pfil/51/pict.jpg</imageLink>
#         <iso3166CountryCode>US</iso3166CountryCode>
#         <longTermImpact>Create an atmosphere where teachers spend less time maintaining discipline and more time teaching, where teachers teach students to think critically and solve problems, and finally, where children feel safe and can focus on learning.</longTermImpact>
#         <need>A child's success in life depends to a great extent on the quality of education the child receives. This is especially true for children living in impoverished communities.  Center for Artistry in Teaching is reengineering the way teachers see themselves and the way they teach - to include their total mind, heart, and body, while incorporating spontaneity, critical thinking, and problem solving. The result is a re-energized educator who engages in the art of teaching.</need>
#         <numberOfDonations>0</numberOfDonations>
#         <organization>
#             <activeProjects>0</activeProjects>
#             <addressLine1>1421 22nd St., NW</addressLine1>
#             <addressLine2></addressLine2>
#             <city>Washington</city>
#             <countries>
#                 <country>
#                     <iso3166CountryCode>US</iso3166CountryCode>
#                     <name>United States</name>
#                 </country>
#             </countries>
#             <country>United States</country>
#             <id>31</id>
#             <iso3166CountryCode>US</iso3166CountryCode>
#             <mission>Most teachers teach students what to think. CAT teachers teach students how to think. Through innovative programs for teachers, CAT is leading a teacher-driven movement to reform public schools. By preparing children to learn and strengthening teachers’ skills, CAT is transforming the way teaching and learning take place in US schools.  CAT is at a critical stage in its organizational development, poised to double the number of teachers we reach each year.</mission>
#             <name>Center for Artistry in Teaching (CAT)</name>
#             <postal>20037</postal>
#             <state>DC</state>
#             <themes>
#                 <theme>
#                     <id>edu</id>
#                     <name>Education</name>
#                 </theme>
#             </themes>
#             <totalProjects>1</totalProjects>
#             <url>http://www.artistryinteaching.org</url>
#         </organization>
#         <progressReportLink>https://www.globalgiving.org/projects/workshop-in-the-art-of-teaching/updates/</progressReportLink>
#         <projectLink>https://www.globalgiving.org/projects/workshop-in-the-art-of-teaching/</projectLink>
#         <region>North America</region>
#         <remaining>22000.00</remaining>
#         <status>retired</status>
#         <summary>The quality of a child's teachers has an enormous impact on that child's chances for success in life. The Workshop in the Art of Teaching improves the effectiveness of teachers.</summary>
#         <themeName>Education</themeName>
#         <title>Workshop in the Art of Teaching</title>
#         <type>project</type>
#     </project>
#     <project>
#         <active>false</active>
#         <activities> </activities>
#         <additionalDocumentation>https://www.globalgiving.org/pfil/254/projdoc.doc</additionalDocumentation>
#         <approvedDate>2003-08-31T16:00:36-04:00</approvedDate>
#         <contactAddress>Village Emporium</contactAddress>
#         <contactAddress2>114 Jefferson Street S.</contactAddress2>
#         <contactCity>Wadena</contactCity>
#         <contactCountry>United States</contactCountry>
#         <contactPostal>56482</contactPostal>
#         <contactState>Minnesota</contactState>
#         <contactUrl>http://www.q-connections.org</contactUrl>
#         <country>United States</country>
#         <funding>0.00</funding>
#         <goal>7000.00</goal>
#         <id>254</id>
#         <image id="0">
#             <imagelink size="small">
#                 <url>https://www.globalgiving.org/share/dfltpict.jpg</url>
#             </imagelink>
#             <imagelink size="thumbnail">
#                 <url>https://www.globalgiving.org/share/dfltpict.jpg</url>
#             </imagelink>
#             <imagelink size="medium">
#                 <url>https://www.globalgiving.org/share/dfltpict.jpg</url>
#             </imagelink>
#             <imagelink size="large">
#                 <url>https://www.globalgiving.org/share/dfltpict.jpg</url>
#             </imagelink>
#             <imagelink size="extraLarge">
#                 <url>https://www.globalgiving.org/share/dfltpict.jpg</url>
#             </imagelink>
#             <imagelink size="original">
#                 <url>https://www.globalgiving.org/share/dfltpict.jpg</url>
#             </imagelink>
#             <title>QC Resource Center for World Development Minnesota</title>
#
#         <imageLink>https://www.globalgiving.org/share/dfltpict.jpg</imageLink>
#         <iso3166CountryCode>US</iso3166CountryCode>
#         <longTermImpact></longTermImpact>
#         <need>Education about other cultures, the world economy and developing countries is needed in our society. Access is facilitated where there is a center offering services to a broad range of people and groups. It will recruit volunteers who want to travel to the developing world. The center needs income</need>
#         <numberOfDonations>0</numberOfDonations>
#         <organization>
#             <activeProjects>0</activeProjects>
#             <addressLine1>28503 Ottawa Drive</addressLine1>
#             <addressLine2></addressLine2>
#             <city>Browerville</city>
#             <countries>
#                 <country>
#                     <iso3166CountryCode>EC</iso3166CountryCode>
#                     <name>Ecuador</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>GH</iso3166CountryCode>
#                     <name>Ghana</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>SL</iso3166CountryCode>
#                     <name>Sierra Leone</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>US</iso3166CountryCode>
#                     <name>United States</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>ZM</iso3166CountryCode>
#                     <name>Zambia</name>
#                 </country>
#             </countries>
#             <country>United States</country>
#             <ein>41-1983907</ein>
#             <id>181</id>
#             <iso3166CountryCode>US</iso3166CountryCode>
#             <mission>To help build a more just and sustainable world by creating global partnerships.&#xD;
# It does this &#xD;
# -by linking individuals and groups who are seeking global partnerships and opportunities&#xD;
# -by promoting responsible and meaningful travel and tourism experiences&#xD;
# - - by facilitating communication and learning through the supply of computers to partners&#xD;
# - and by providing opportunities for multi-cultural experience</mission>
#             <name>Quantum Connections - Creating Global Partnerships</name>
#             <postal>56438</postal>
#             <state>Minnesota</state>
#             <themes>
#                 <theme>
#                     <id>ecdev</id>
#                     <name>Economic Development</name>
#                 </theme>
#                 <theme>
#                     <id>edu</id>
#                     <name>Education</name>
#                 </theme>
#                 <theme>
#                     <id>env</id>
#                     <name>Environment</name>
#                 </theme>
#             </themes>
#             <totalProjects>5</totalProjects>
#             <url>http://www.q-connections.org</url>
#         </organization>
#         <progressReportLink>https://www.globalgiving.org/projects/qc-resource-center-for-world-development-minnesota/updates/</progressReportLink>
#         <projectLink>https://www.globalgiving.org/projects/qc-resource-center-for-world-development-minnesota/</projectLink>
#         <region>North America</region>
#         <remaining>7000.00</remaining>
#         <status>retired</status>
#         <summary>A center, with coffee house, focussed on world development and on justice and peace. Resources available to schoolsand colleges  in central Minnesota to enable people to Think Globally, Act Locally.</summary>
#         <themeName>Economic Development</themeName>
#         <title>QC Resource Center for World Development Minnesota</title>
#         <type>project</type>
#     </project>
#     <project>
#         <active>false</active>
#         <activities>It ensures that more GlobalGiving projects receive the funding necessary to begin implementation.</activities>
#         <additionalDocumentation>https://www.globalgiving.org/pfil/284/projdoc.doc</additionalDocumentation>
#         <approvedDate>2003-10-14T13:08:05-04:00</approvedDate>
#         <contactAddress>1816 12th St NW, 3rd floor</contactAddress>
#         <contactCity>Washington</contactCity>
#         <contactCountry>United States</contactCountry>
#         <contactPostal>20009</contactPostal>
#         <contactState>DC</contactState>
#         <contactUrl>http://www.globalgiving.com</contactUrl>
#         <country>United States</country>
#         <funding>7344.70</funding>
#         <goal>100000.00</goal>
#         <id>284</id>
#         <image id="0">
#             <imagelink size="small">
#                 <url>https://www.globalgiving.org/pfil/284/pict_grid1.jpg</url>
#             </imagelink>
#             <imagelink size="thumbnail">
#                 <url>https://www.globalgiving.org/pfil/284/pict_thumbnail.jpg</url>
#             </imagelink>
#             <imagelink size="medium">
#                 <url>https://www.globalgiving.org/pfil/284/pict_med.jpg</url>
#             </imagelink>
#             <imagelink size="large">
#                 <url>https://www.globalgiving.org/pfil/284/pict_grid7.jpg</url>
#             </imagelink>
#             <imagelink size="extraLarge">
#                 <url>https://www.globalgiving.org/pfil/284/pict_large.jpg</url>
#             </imagelink>
#             <imagelink size="original">
#                 <url>https://www.globalgiving.org/pfil/284/pict_original.jpg</url>
#             </imagelink>
#             <title>GlobalGiving Matching Fund</title>
#
#         <imageGallerySize>1</imageGallerySize>
#         <imageLink>https://www.globalgiving.org/pfil/284/pict.jpg</imageLink>
#         <iso3166CountryCode>US</iso3166CountryCode>
#         <longTermImpact>The goal of GlobalGiving's matching fund is to provide donors with another high-impact giving opportunity without making them have to specify a project.</longTermImpact>
#         <need>The GlobalGiving matching fund uses donations to support those projects that are closest to reaching their funding objective.  It is a terrific option for those donors in a hurry or those that can't make up their mind.</need>
#         <numberOfDonations>6</numberOfDonations>
#         <organization>
#             <activeProjects>30</activeProjects>
#             <addressLine1>1110 Vermont Avenue NW</addressLine1>
#             <addressLine2>Suite 550</addressLine2>
#             <city>Washington</city>
#             <countries>
#                 <country>
#                     <iso3166CountryCode>AF</iso3166CountryCode>
#                     <name>Afghanistan</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>BD</iso3166CountryCode>
#                     <name>Bangladesh</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>BR</iso3166CountryCode>
#                     <name>Brazil</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>BF</iso3166CountryCode>
#                     <name>Burkina Faso</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>KH</iso3166CountryCode>
#                     <name>Cambodia</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>TD</iso3166CountryCode>
#                     <name>Chad</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>CL</iso3166CountryCode>
#                     <name>Chile</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>CN</iso3166CountryCode>
#                     <name>China</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>CR</iso3166CountryCode>
#                     <name>Costa Rica</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>CD</iso3166CountryCode>
#                     <name>Congo, Democratic Republic of the</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>DJ</iso3166CountryCode>
#                     <name>Djibouti</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>ET</iso3166CountryCode>
#                     <name>Ethiopia</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>FI</iso3166CountryCode>
#                     <name>Finland</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>GT</iso3166CountryCode>
#                     <name>Guatemala</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>GY</iso3166CountryCode>
#                     <name>Guyana</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>HT</iso3166CountryCode>
#                     <name>Haiti</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>HK</iso3166CountryCode>
#                     <name>Hong Kong</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>IN</iso3166CountryCode>
#                     <name>India</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>ID</iso3166CountryCode>
#                     <name>Indonesia</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>IT</iso3166CountryCode>
#                     <name>Italy</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>JP</iso3166CountryCode>
#                     <name>Japan</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>KE</iso3166CountryCode>
#                     <name>Kenya</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>MW</iso3166CountryCode>
#                     <name>Malawi</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>MY</iso3166CountryCode>
#                     <name>Malaysia</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>ML</iso3166CountryCode>
#                     <name>Mali</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>MR</iso3166CountryCode>
#                     <name>Mauritania</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>MA</iso3166CountryCode>
#                     <name>Morocco</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>MM</iso3166CountryCode>
#                     <name>Myanmar</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>NA</iso3166CountryCode>
#                     <name>Namibia</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>NP</iso3166CountryCode>
#                     <name>Nepal</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>NZ</iso3166CountryCode>
#                     <name>New Zealand</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>NE</iso3166CountryCode>
#                     <name>Niger</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>PK</iso3166CountryCode>
#                     <name>Pakistan</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>PY</iso3166CountryCode>
#                     <name>Paraguay</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>PH</iso3166CountryCode>
#                     <name>Philippines</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>RW</iso3166CountryCode>
#                     <name>Rwanda</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>SN</iso3166CountryCode>
#                     <name>Senegal</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>SL</iso3166CountryCode>
#                     <name>Sierra Leone</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>SO</iso3166CountryCode>
#                     <name>Somalia</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>ZA</iso3166CountryCode>
#                     <name>South Africa</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>KR</iso3166CountryCode>
#                     <name>South Korea</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>ES</iso3166CountryCode>
#                     <name>Spain</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>LK</iso3166CountryCode>
#                     <name>Sri Lanka</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>SD</iso3166CountryCode>
#                     <name>Sudan</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>TZ</iso3166CountryCode>
#                     <name>Tanzania, United Republic of</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>TH</iso3166CountryCode>
#                     <name>Thailand</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>TR</iso3166CountryCode>
#                     <name>Turkey</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>UG</iso3166CountryCode>
#                     <name>Uganda</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>GB</iso3166CountryCode>
#                     <name>United Kingdom</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>US</iso3166CountryCode>
#                     <name>United States</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>VN</iso3166CountryCode>
#                     <name>Vietnam</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>WS</iso3166CountryCode>
#                     <name>Samoa</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>ZM</iso3166CountryCode>
#                     <name>Zambia</name>
#                 </country>
#             </countries>
#             <country>United States</country>
#             <ein>30-0108263</ein>
#             <id>189</id>
#             <iso3166CountryCode>US</iso3166CountryCode>
#             <logoUrl>https://dpqe0zkrjo0ak.cloudfront.net/pfil/organ/189/orglogo.jpg</logoUrl>
#             <mission>Our mission is to build an efficient, open, thriving marketplace that connects people who have community and world-changing ideas with people who can support them.</mission>
#             <name>GlobalGiving</name>
#             <postal>20005</postal>
#             <state>D.C.</state>
#             <themes>
#                 <theme>
#                     <id>animals</id>
#                     <name>Animals</name>
#                 </theme>
#                 <theme>
#                     <id>children</id>
#                     <name>Children</name>
#                 </theme>
#                 <theme>
#                     <id>democ</id>
#                     <name>Democracy and Governance</name>
#                 </theme>
#                 <theme>
#                     <id>disaster</id>
#                     <name>Disaster Recovery</name>
#                 </theme>
#                 <theme>
#                     <id>ecdev</id>
#                     <name>Economic Development</name>
#                 </theme>
#                 <theme>
#                     <id>edu</id>
#                     <name>Education</name>
#                 </theme>
#                 <theme>
#                     <id>env</id>
#                     <name>Environment</name>
#                 </theme>
#                 <theme>
#                     <id>finance</id>
#                     <name>Microfinance</name>
#                 </theme>
#                 <theme>
#                     <id>gender</id>
#                     <name>Women and Girls</name>
#                 </theme>
#                 <theme>
#                     <id>health</id>
#                     <name>Health</name>
#                 </theme>
#                 <theme>
#                     <id>rights</id>
#                     <name>Human Rights</name>
#                 </theme>
#                 <theme>
#                     <id>tech</id>
#                     <name>Technology</name>
#                 </theme>
#                 <theme>
#                     <id>hunger</id>
#                     <name>Hunger</name>
#                 </theme>
#             </themes>
#             <totalProjects>96</totalProjects>
#             <url>https://www.globalgiving.org</url>
#         </organization>
#         <progressReportLink>https://www.globalgiving.org/projects/globalgiving-matching-fund/updates/</progressReportLink>
#         <projectLink>https://www.globalgiving.org/projects/globalgiving-matching-fund/</projectLink>
#         <region>North America</region>
#         <remaining>92655.30</remaining>
#         <status>retired</status>
#         <summary>GlobalGiving's matching fund allows donors to contribute to a general pool that will allow projects that are almost fully funded, reach their budget target.</summary>
#         <themeName>Economic Development</themeName>
#         <title>GlobalGiving Matching Fund</title>
#         <type>project</type>
#     </project>
#     <project>
#         <active>false</active>
#         <activities>To purchase and scan 100 books that have been requested by teachers and parents. Ten of these will be textbooks that will be proofread for perfect text accuracy. All 100 will be shared nationwide through the Bookshare.org online collection.</activities>
#         <additionalDocumentation>https://www.globalgiving.org/pfil/367/projdoc.doc</additionalDocumentation>
#         <approvedDate>2004-06-01T12:43:32-04:00</approvedDate>
#         <contactAddress>480 S. California Ave</contactAddress>
#         <contactAddress2>Suite 201</contactAddress2>
#         <contactCity>Palo Alto</contactCity>
#         <contactCountry>United States</contactCountry>
#         <contactPostal>94306</contactPostal>
#         <contactState>California</contactState>
#         <contactUrl>http://www.bookshare.org</contactUrl>
#         <country>United States</country>
#         <funding>745.00</funding>
#         <goal>5060.00</goal>
#         <id>367</id>
#         <image id="0">
#             <imagelink size="small">
#                 <url>https://www.globalgiving.org/pfil/367/pict_grid1.jpg</url>
#             </imagelink>
#             <imagelink size="thumbnail">
#                 <url>https://www.globalgiving.org/pfil/367/pict_thumbnail.jpg</url>
#             </imagelink>
#             <imagelink size="medium">
#                 <url>https://www.globalgiving.org/pfil/367/pict_med.jpg</url>
#             </imagelink>
#             <imagelink size="large">
#                 <url>https://www.globalgiving.org/pfil/367/pict_grid7.jpg</url>
#             </imagelink>
#             <imagelink size="extraLarge">
#                 <url>https://www.globalgiving.org/pfil/367/pict_large.jpg</url>
#             </imagelink>
#             <imagelink size="original">
#                 <url>https://www.globalgiving.org/pfil/367/pict_original.jpg</url>
#             </imagelink>
#             <title>Accessible Books for Students with Disabilities</title>
#
#         <imageGallerySize>3</imageGallerySize>
#         <imageLink>https://www.globalgiving.org/pfil/367/pict.jpg</imageLink>
#         <iso3166CountryCode>US</iso3166CountryCode>
#         <longTermImpact>This project will help to develop a core collection of K-12 books to serve students with disabilities.</longTermImpact>
#         <need>Fewer than 5% of books are produced in formats that are accessible to people who have visual or learning disabilities.  To read other books, more than three million US residents, including one million students, are forced to laboriously scan them into computers.  In particular, K-12 students need accessible textbooks and outside reading material.  Schools are legally required to offer textbooks in these formats, but access is often inadequate and little supplemental reading is made available.</need>
#         <numberOfDonations>1</numberOfDonations>
#         <organization>
#             <activeProjects>0</activeProjects>
#             <addressLine1>480 S. California Ave Suite 201</addressLine1>
#             <addressLine2></addressLine2>
#             <city>Palo Alto</city>
#             <countries>
#                 <country>
#                     <iso3166CountryCode>BD</iso3166CountryCode>
#                     <name>Bangladesh</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>GT</iso3166CountryCode>
#                     <name>Guatemala</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>IN</iso3166CountryCode>
#                     <name>India</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>US</iso3166CountryCode>
#                     <name>United States</name>
#                 </country>
#             </countries>
#             <country>United States</country>
#             <ein>77-0225904</ein>
#             <id>200</id>
#             <iso3166CountryCode>US</iso3166CountryCode>
#             <mission>Benetech is a Silicon Valley nonprofit that develops technology projects addressing major social problems in areas such as disability, human rights, literacy and education. Our predecessor nonprofit, Arkenstone, was founded in 1989 to provide reading tools for people with disabilities. It helped 35,000 visually impaired people in 60 countries to live and work independently before the sale of its business operations to a for-profit company in 2000, which led to the launch of Benetech.&#xD;
# </mission>
#             <name>Benetech</name>
#             <postal>94306</postal>
#             <state>CA</state>
#             <themes>
#                 <theme>
#                     <id>edu</id>
#                     <name>Education</name>
#                 </theme>
#                 <theme>
#                     <id>rights</id>
#                     <name>Human Rights</name>
#                 </theme>
#                 <theme>
#                     <id>tech</id>
#                     <name>Technology</name>
#                 </theme>
#             </themes>
#             <totalProjects>6</totalProjects>
#             <url>http://www.benetech.org</url>
#         </organization>
#         <progressReportLink>https://www.globalgiving.org/projects/students-with-disabilities-1/updates/</progressReportLink>
#         <projectLink>https://www.globalgiving.org/projects/students-with-disabilities-1/</projectLink>
#         <region>North America</region>
#         <remaining>4315.00</remaining>
#         <status>funded</status>
#         <summary>Adding more accessible textbooks and supplemental reading material for K-12 students with visual and learning disabilities to the Bookshare.org online collection.</summary>
#         <themeName>Education</themeName>
#         <title>Accessible Books for Students with Disabilities</title>
#         <type>project</type>
#     </project>
#     <project>
#         <active>true</active>
#         <activities>This fund ensures that more GlobalGiving projects receive the funding necessary to begin implementation.</activities>
#         <additionalDocumentation>https://www.globalgiving.org/pfil/554/projdoc.pdf</additionalDocumentation>
#         <approvedDate>2004-06-01T12:45:32-04:00</approvedDate>
#         <contactAddress>1023, 15th Street, Suite 1200</contactAddress>
#         <contactCity>Washington</contactCity>
#         <contactCountry>United States</contactCountry>
#         <contactName>Britt Lake</contactName>
#         <contactPostal>20005</contactPostal>
#         <contactState>D.C.</contactState>
#         <contactUrl>http://www.globalgiving.org</contactUrl>
#         <country>United States</country>
#         <donationOptions>
#             <donationOption>
#                 <amount>15</amount>
#                 <description>Matching funds and incentives for GlobalGiving projects</description>
#             </donationOption>
#             <donationOption>
#                 <amount>50</amount>
#                 <description>Matching funds and incentives for GlobalGiving projects</description>
#             </donationOption>
#             <donationOption>
#                 <amount>150</amount>
#                 <description>Matching funds and incentives for GlobalGiving projects</description>
#             </donationOption>
#             <donationOption>
#                 <amount>500</amount>
#                 <description>Matching funds and incentives for GlobalGiving projects</description>
#             </donationOption>
#             <donationOption>
#                 <amount>1000</amount>
#                 <description>Matching funds and incentives for GlobalGiving projects</description>
#             </donationOption>
#         </donationOptions>
#         <funding>1556238.39</funding>
#         <goal>2000000.00</goal>
#         <id>554</id>
#         <image id="0">
#             <imagelink size="small">
#                 <url>https://www.globalgiving.org/pfil/554/pict_grid1.jpg</url>
#             </imagelink>
#             <imagelink size="thumbnail">
#                 <url>https://www.globalgiving.org/pfil/554/pict_thumbnail.jpg</url>
#             </imagelink>
#             <imagelink size="medium">
#                 <url>https://www.globalgiving.org/pfil/554/pict_med.jpg</url>
#             </imagelink>
#             <imagelink size="large">
#                 <url>https://www.globalgiving.org/pfil/554/pict_grid7.jpg</url>
#             </imagelink>
#             <imagelink size="extraLarge">
#                 <url>https://www.globalgiving.org/pfil/554/pict_large.jpg</url>
#             </imagelink>
#             <imagelink size="original">
#                 <url>https://www.globalgiving.org/pfil/554/pict_original.jpg</url>
#             </imagelink>
#             <title>GlobalGiving Fund</title>
#
#         <imageGallerySize>1</imageGallerySize>
#         <imageLink>https://www.globalgiving.org/pfil/554/pict.jpg</imageLink>
#         <iso3166CountryCode>US</iso3166CountryCode>
#         <latitude>38.92020034790039</latitude>
#         <longTermImpact>Since 2008, every dollar that has been donated to this fund has resulted in an average of $6 reaching a project through an incentive campaign. This means that your donation generates 6x impact when supporting the GlobalGiving Fund.</longTermImpact>
#         <longitude>-77.03750610351562</longitude>
#         <need>This fund will support all the projects on the GlobalGiving website.  Donations will be used to provide incentives like matching funds and bonuses during campaigns and bonus days for existing and new projects. A portion of the fund may also go to support GlobalGiving's operations so that we can serve more organizations and projects.</need>
#         <numberOfDonations>28381</numberOfDonations>
#         <organization>
#             <activeProjects>30</activeProjects>
#             <addressLine1>1110 Vermont Avenue NW</addressLine1>
#             <addressLine2>Suite 550</addressLine2>
#             <city>Washington</city>
#             <countries>
#                 <country>
#                     <iso3166CountryCode>AF</iso3166CountryCode>
#                     <name>Afghanistan</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>BD</iso3166CountryCode>
#                     <name>Bangladesh</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>BR</iso3166CountryCode>
# ...
#         <numberOfDonations>18</numberOfDonations>
#         <organization>
#             <activeProjects>0</activeProjects>
#             <addressLine1>4557 Melan Dr. S.</addressLine1>
#             <addressLine2></addressLine2>
#             <city>Fairbanks</city>
#             <countries>
#                 <country>
#                     <iso3166CountryCode>US</iso3166CountryCode>
#                     <name>United States</name>
#                 </country>
#             </countries>
#             <country>United States</country>
#             <ein>64-6221541</ein>
#             <id>205</id>
#             <iso3166CountryCode>US</iso3166CountryCode>
#             <logoUrl>https://dpqe0zkrjo0ak.cloudfront.net/pfil/organ/205/orglogo.gif</logoUrl>
#             <mission>To generate and distribute electronic literature.</mission>
#             <name>The Project Gutenberg Literary Archive Foundation</name>
#             <postal>99712</postal>
#             <state>AK</state>
#             <themes>
#                 <theme>
#                     <id>edu</id>
#                     <name>Education</name>
#                 </theme>
#             </themes>
#             <totalProjects>1</totalProjects>
#             <url>http://www.GUTENBERG.NET</url>
#         </organization>
#         <progressReportLink>https://www.globalgiving.org/projects/project-gutenberg/updates/</progressReportLink>
#         <projectLink>https://www.globalgiving.org/projects/project-gutenberg/</projectLink>
#         <region>North America</region>
#         <remaining>50000.00</remaining>
#         <status>retired</status>
#         <summary>Free electronic literature (eBooks) in many formats and languages which are distributed through a network of sites worldwide. The eBooks are produced by thousands of volunteers.</summary>
#         <themeName>Education</themeName>
#         <title>Project Gutenberg</title>
#         <type>project</type>
#     </project>
#     <project>
#         <active>false</active>
#         <activities>Our worldwide mapmaker network is involved in the updating process. With their help, we will design new/revised Icons, create digital icon fonts, translate definitions and provide multi-lingual database/digital posters and public awareness materials.</activities>
#         <additionalDocumentation>https://www.globalgiving.org/pfil/603/projdoc.pdf</additionalDocumentation>
#         <approvedDate>2006-09-01T09:16:53-04:00</approvedDate>
#         <contactAddress>175 Rivington St. #1D (mailing)</contactAddress>
#         <contactAddress2>220A East 4th Street (location)</contactAddress2>
#         <contactCity>New York</contactCity>
#         <contactCountry>United States</contactCountry>
#         <contactName>Wendy E. Brawer</contactName>
#         <contactPostal>10009</contactPostal>
#         <contactState>NY</contactState>
#         <contactTitle>Founding Director &amp; Secretary</contactTitle>
#         <contactUrl>http://www.greenmap.org</contactUrl>
#         <country>United States</country>
#         <donationOptions>
#             <donationOption>
#                 <amount>10</amount>
#                 <description>Equips 2 developing world Green Map projects.</description>
#             </donationOption>
#             <donationOption>
#                 <amount>25</amount>
#                 <description>Provides teacher-training workshop with Green Map-making resources.</description>
#             </donationOption>
#             <donationOption>
#                 <amount>50</amount>
#                 <description>Provides hundreds with digital Icon poster in their local language.</description>
#             </donationOption>
#         </donationOptions>
#         <funding>268.00</funding>
#         <goal>27500.00</goal>
#         <id>603</id>
#         <image id="0">
#             <imagelink size="small">
#                 <url>https://www.globalgiving.org/pfil/603/pict_grid1.jpg</url>
#             </imagelink>
#             <imagelink size="thumbnail">
#                 <url>https://www.globalgiving.org/pfil/603/pict_thumbnail.jpg</url>
#             </imagelink>
#             <imagelink size="medium">
#                 <url>https://www.globalgiving.org/pfil/603/pict_med.jpg</url>
#             </imagelink>
#             <imagelink size="large">
#                 <url>https://www.globalgiving.org/pfil/603/pict_grid7.jpg</url>
#             </imagelink>
#             <imagelink size="extraLarge">
#                 <url>https://www.globalgiving.org/pfil/603/pict_large.jpg</url>
#             </imagelink>
#             <imagelink size="original">
#                 <url>https://www.globalgiving.org/pfil/603/pict_original.jpg</url>
#             </imagelink>
#             <title>Icons for Mapping Community Sustainability</title>
#
#         <imageGallerySize>4</imageGallerySize>
#         <imageLink>https://www.globalgiving.org/pfil/603/pict.jpg</imageLink>
#         <iso3166CountryCode>US</iso3166CountryCode>
#         <latitude>40.72618865966797</latitude>
#         <longTermImpact>Updated Icons will extend our ability to spur local action for a greener future, benefiting many more communities. We will distribute Green Map Icon resources in both printed and digital formats, making extra effort to reach under-served communities.</longTermImpact>
#         <longitude>-73.9795913696289</longitude>
#         <need>Green Map is updating its award-winning Icons. The world’s only universal iconography for use on maps, these 125 symbols are already helping more than 400 communities in 50 countries highlight sustainable living resources and address ecological and cultural issues on locally-made Green Maps. Update process is collaborative, and will result in a more current and effective shared set of Icons, reflecting the diversity of all participating communities, today and in the future.</need>
#         <numberOfDonations>16</numberOfDonations>
#         <organization>
#             <activeProjects>2</activeProjects>
#             <addressLine1>175 Rivington #1D</addressLine1>
#             <addressLine2></addressLine2>
#             <city>New York</city>
#             <countries>
#                 <country>
#                     <iso3166CountryCode>AL</iso3166CountryCode>
#                     <name>Albania</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>AU</iso3166CountryCode>
#                     <name>Australia</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>AT</iso3166CountryCode>
#                     <name>Austria</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>BE</iso3166CountryCode>
#                     <name>Belgium</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>BA</iso3166CountryCode>
#                     <name>Bosnia and Herzegovina</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>BR</iso3166CountryCode>
#                     <name>Brazil</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>CA</iso3166CountryCode>
#                     <name>Canada</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>CN</iso3166CountryCode>
#                     <name>China</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>CO</iso3166CountryCode>
#                     <name>Colombia</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>CU</iso3166CountryCode>
#                     <name>Cuba</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>CZ</iso3166CountryCode>
#                     <name>Czech Republic</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>DK</iso3166CountryCode>
#                     <name>Denmark</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>EE</iso3166CountryCode>
#                     <name>Estonia</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>FI</iso3166CountryCode>
#                     <name>Finland</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>FR</iso3166CountryCode>
#                     <name>France</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>DE</iso3166CountryCode>
#                     <name>Germany</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>HK</iso3166CountryCode>
#                     <name>Hong Kong</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>HU</iso3166CountryCode>
#                     <name>Hungary</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>IS</iso3166CountryCode>
#                     <name>Iceland</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>IN</iso3166CountryCode>
#                     <name>India</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>ID</iso3166CountryCode>
#                     <name>Indonesia</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>IE</iso3166CountryCode>
#                     <name>Ireland</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>IL</iso3166CountryCode>
#                     <name>Israel</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>IT</iso3166CountryCode>
#                     <name>Italy</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>JP</iso3166CountryCode>
#                     <name>Japan</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>LV</iso3166CountryCode>
#                     <name>Latvia</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>LB</iso3166CountryCode>
#                     <name>Lebanon</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>LT</iso3166CountryCode>
#                     <name>Lithuania</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>MX</iso3166CountryCode>
#                     <name>Mexico</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>NL</iso3166CountryCode>
#                     <name>Netherlands</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>NG</iso3166CountryCode>
#                     <name>Nigeria</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>NO</iso3166CountryCode>
#                     <name>Norway</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>PR</iso3166CountryCode>
#                     <name>Puerto Rico</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>RO</iso3166CountryCode>
#                     <name>Romania</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>SG</iso3166CountryCode>
#                     <name>Singapore</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>ZA</iso3166CountryCode>
#                     <name>South Africa</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>KR</iso3166CountryCode>
#                     <name>South Korea</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>ES</iso3166CountryCode>
#                     <name>Spain</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>SE</iso3166CountryCode>
#                     <name>Sweden</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>CH</iso3166CountryCode>
#                     <name>Switzerland</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>TW</iso3166CountryCode>
#                     <name>Taiwan</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>TH</iso3166CountryCode>
#                     <name>Thailand</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>GM</iso3166CountryCode>
#                     <name>Gambia, The</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>UG</iso3166CountryCode>
#                     <name>Uganda</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>AE</iso3166CountryCode>
#                     <name>United Arab Emirates</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>GB</iso3166CountryCode>
#                     <name>United Kingdom</name>
#                 </country>
#                 <country>
#                     <iso3166CountryCode>US</iso3166CountryCode>
#                     <name>United States</name>
#                 </country>
#             </countries>
#             <country>United States</country>
#             <ein>13-4062364</ein>
#             <id>209</id>
#             <iso3166CountryCode>US</iso3166CountryCode>
#             <logoUrl>https://dpqe0zkrjo0ak.cloudfront.net/pfil/organ/209/orglogo.jpg</logoUrl>
#             <mission>Engaging communities worldwide to chart a sustainable future - for all of us!
#
# We empower a diverse perspective-changing movement mapping local natural, social and cultural resources in 950+ diverse cities, villages and neighborhoods in over 65 countries. Developing local sustainability networks since 1995, Green Map System expands the demand for healthy, green choices with our adaptable, experiential and interactive mapmaking resources and universal icons, multilingual websites, workshops and regional hubs.</mission>
#             <name>Green Map System</name>
#             <postal>10002</postal>
#             <state>NY</state>
#             <themes>
#                 <theme>
#                     <id>climate</id>
#                     <name>Climate Change</name>
#                 </theme>
#                 <theme>
#                     <id>ecdev</id>
#                     <name>Economic Development</name>
#                 </theme>
#                 <theme>
#                     <id>env</id>
#                     <name>Environment</name>
#                 </theme>
#                 <theme>
#                     <id>tech</id>
#                     <name>Technology</name>
#                 </theme>
#             </themes>
#             <totalProjects>7</totalProjects>
#             <url>http://www.greenmap.org</url>
#         </organization>
#         <progressReportLink>https://www.globalgiving.org/projects/sustainable-living-with-green-maps/updates/</progressReportLink>
#         <projectLink>https://www.globalgiving.org/projects/sustainable-living-with-green-maps/</projectLink>
#         <region>North America</region>
#         <remaining>27232.00</remaining>
#         <status>funded</status>
#         <summary>Green Map Icons are a universal language for identifying environmental and cultural resources. Help local mapmakers foster sustainable living by updating this lexicon and a multilingual icon database.</summary>
#         <themeName>Technology</themeName>
#         <title>Icons for Mapping Community Sustainability</title>
#         <type>project</type>
#     </project>
# </projects>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response_text, 'html.parser')
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <projects numberfound="2424">
#  <hasnext>
#   true
#  </hasnext>
#  <nextprojectid>
#   607
#  </nextprojectid>
#  <project>
#   <active>
#    false
#   </active>
#   <activities>
#    Energy healers have been researching the effects of metals and the elements on the health of the human body. CHI plans to hold workshops to train energy healers to utilize various metals and the elements in promoting healthier lifestyles.
#   </activities>
#   <additionaldocumentation>
#    https://www.globalgiving.org/pfil/16/projdoc.doc
#   </additionaldocumentation>
#   <approveddate>
#    2003-05-20T19:40:05-04:00
#   </approveddate>
#   <contactaddress>
#    Creating Hope International
#   </contactaddress>
#   <contactaddress2>
#    P. O. Box 1058
#   </contactaddress2>
#   <contactcity>
#    Dearborn
#   </contactcity>
#   <contactcountry>
#    United States
#   </contactcountry>
#   <contactpostal>
#    48121
#   </contactpostal>
#   <contactstate>
#    Michigan
#   </contactstate>
#   <contacturl>
#    http://www.creatinghope.org
#   </contacturl>
#   <country>
#    United States
#   </country>
#   <funding>
#    0.00
#   </funding>
#   <goal>
#    3300.00
#   </goal>
#   <id>
#    16
#   </id>
#   <image id="0">
#    <imagelink size="small">
#     <url>
#      https://www.globalgiving.org/share/dfltpict.jpg
#     </url>
#    </imagelink>
#    <imagelink size="thumbnail">
#     <url>
#      https://www.globalgiving.org/share/dfltpict.jpg
#     </url>
#    </imagelink>
#    <imagelink size="medium">
#     <url>
#      https://www.globalgiving.org/share/dfltpict.jpg
#     </url>
#    </imagelink>
#    <imagelink size="large">
#     <url>
#      https://www.globalgiving.org/share/dfltpict.jpg
#     </url>
#    </imagelink>
#    <imagelink size="extraLarge">
#     <url>
#      https://www.globalgiving.org/share/dfltpict.jpg
#     </url>
#    </imagelink>
#    <imagelink size="original">
#     <url>
#      https://www.globalgiving.org/share/dfltpict.jpg
#     </url>
#    </imagelink>
#    <title>
#     Improving Health by Complementary Health Practices
#    </title>
#
#   <imagelink>
#    https://www.globalgiving.org/share/dfltpict.jpg
#   </imagelink>
#   <iso3166countrycode>
#    US
#   </iso3166countrycode>
#   <longtermimpact>
#    In these workshops, participants will learn how to help themselves and others through energy healing.
#   </longtermimpact>
#   <need>
#    Americans today expect to live longer than ever before. Unfortunately, increases in life expectancy also mean that people cope with chronic and terminal illnesses for years and even decades. This situation has prompted interest in healing alternatives to complement allopathic medicine. In 2001, Creating Hope International (CHI) began supporting the work of energy healers who have helped and healed many people.
#   </need>
#   <numberofdonations>
#    0
#   </numberofdonations>
#   <organization>
#    <activeprojects>
#     6
#    </activeprojects>
#    <addressline1>
#     Creating Hope International
#    </addressline1>
#    <addressline2>
#     PO Box 1058
#    </addressline2>
#    <city>
#     Dearborn
#    </city>
#    <countries>
#     <country>
#      <iso3166countrycode>
#       AF
#      </iso3166countrycode>
#      <name>
#       Afghanistan
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       IN
#      </iso3166countrycode>
#      <name>
#       India
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       NP
#      </iso3166countrycode>
#      <name>
#       Nepal
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       PK
#      </iso3166countrycode>
#      <name>
#       Pakistan
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       US
#      </iso3166countrycode>
#      <name>
#       United States
#      </name>
#     </country>
#    </countries>
#    <country>
#     United States
#    </country>
#    <ein>
#     38-3288402
#    </ein>
#    <id>
#     254
#    </id>
#    <iso3166countrycode>
#     US
#    </iso3166countrycode>
#    <logourl>
#     https://dpqe0zkrjo0ak.cloudfront.net/pfil/organ/254/orglogo.jpg
#    </logourl>
#    <mission>
#     Creating Hope International (CHI) was founded with the vision of bringing hope to victims of war, political unrest, and natural disasters through programs designed to help them rebuild their lives for a brighter tomorrow. CHI's mission is to empower grassroots organizations that provide education, training, and health care to needy people. CHI supports organizations that respond to community needs on an individual level, foster community participation and utilize culturally sensitive education and training.
#    </mission>
#    <name>
#     Creating Hope International (CHI)
#    </name>
#    <postal>
#     48121
#    </postal>
#    <state>
#     Michigan
#    </state>
#    <themes>
#     <theme>
#      <id>
#       children
#      </id>
#      <name>
#       Children
#      </name>
#     </theme>
#     <theme>
#      <id>
#       democ
#      </id>
#      <name>
#       Democracy and Governance
#      </name>
#     </theme>
#     <theme>
#      <id>
#       disaster
#      </id>
#      <name>
#       Disaster Recovery
#      </name>
#     </theme>
#     <theme>
#      <id>
#       ecdev
#      </id>
#      <name>
#       Economic Development
#      </name>
#     </theme>
#     <theme>
#      <id>
#       edu
#      </id>
#      <name>
#       Education
#      </name>
#     </theme>
#     <theme>
#      <id>
#       env
#      </id>
#      <name>
#       Environment
#      </name>
#     </theme>
#     <theme>
#      <id>
#       gender
#      </id>
#      <name>
#       Women and Girls
#      </name>
#     </theme>
#     <theme>
#      <id>
#       health
#      </id>
#      <name>
#       Health
#      </name>
#     </theme>
#     <theme>
#      <id>
#       human
#      </id>
#      <name>
#       Humanitarian Assistance
#      </name>
#     </theme>
#     <theme>
#      <id>
#       rights
#      </id>
#      <name>
#       Human Rights
#      </name>
#     </theme>
#     <theme>
#      <id>
#       hunger
#      </id>
#      <name>
#       Hunger
#      </name>
#     </theme>
#     <theme>
#      <id>
#       art
#      </id>
#      <name>
#       Arts and Culture
#      </name>
#     </theme>
#    </themes>
#    <totalprojects>
#     138
#    </totalprojects>
#    <url>
#     http://www.creatinghope.org
#    </url>
#   </organization>
#   <progressreportlink>
#    https://www.globalgiving.org/projects/improving-health-by-complementary-health-practices/updates/
#   </progressreportlink>
#   <projectlink>
#    https://www.globalgiving.org/projects/improving-health-by-complementary-health-practices/
#   </projectlink>
#   <region>
#    North America
#   </region>
#   <remaining>
#    3300.00
#   </remaining>
#   <status>
#    retired
#   </status>
#   <summary>
#    Opening doors to better health through research and workshops on energy healing as a complementary alternative to allopathic medicine.
#   </summary>
#   <themename>
#    Health
#   </themename>
#   <title>
#    Improving Health by Complementary Health Practices
#   </title>
#   <type>
#    project
#   </type>
#  </project>
#  <project>
#   <active>
#    false
#   </active>
#   <activities>
#    To purchase and scan 100 books that have been requested by teachers and parents. Ten of these will be textbooks that will be proofread for perfect text accuracy. All 100 will be shared nationwide through the Bookshare.org online collection.
#   </activities>
#   <additionaldocumentation>
#    https://www.globalgiving.org/pfil/31/projdoc.doc
#   </additionaldocumentation>
#   <approveddate>
#    2003-05-30T16:38:38-04:00
#   </approveddate>
#   <contactaddress>
#    480 S. California Ave
#   </contactaddress>
#   <contactaddress2>
#    Suite 201
#   </contactaddress2>
#   <contactcity>
#    Palo Alto
#   </contactcity>
#   <contactcountry>
#    United States
#   </contactcountry>
#   <contactname>
#    James Fruchterman
#   </contactname>
#   <contactpostal>
#    94306
#   </contactpostal>
#   <contactstate>
#    California
#   </contactstate>
#   <contacttitle>
#    President and CEO
#   </contacttitle>
#   <contacturl>
#    http://www.benetech.org
#   </contacturl>
#   <country>
#    United States
#   </country>
#   <funding>
#    2420.00
#   </funding>
#   <goal>
#    5060.00
#   </goal>
#   <id>
#    31
#   </id>
#   <image id="0">
#    <imagelink size="small">
#     <url>
#      https://www.globalgiving.org/pfil/31/pict_grid1.jpg
#     </url>
#    </imagelink>
#    <imagelink size="thumbnail">
#     <url>
#      https://www.globalgiving.org/pfil/31/pict_thumbnail.jpg
#     </url>
#    </imagelink>
#    <imagelink size="medium">
#     <url>
#      https://www.globalgiving.org/pfil/31/pict_med.jpg
#     </url>
#    </imagelink>
#    <imagelink size="large">
#     <url>
#      https://www.globalgiving.org/pfil/31/pict_grid7.jpg
#     </url>
#    </imagelink>
#    <imagelink size="extraLarge">
#     <url>
#      https://www.globalgiving.org/pfil/31/pict_large.jpg
#     </url>
#    </imagelink>
#    <imagelink size="original">
#     <url>
#      https://www.globalgiving.org/pfil/31/pict_original.jpg
#     </url>
#    </imagelink>
#    <title>
#     Accessible Books for Students with Disabilities
#    </title>
#
#   <imagegallerysize>
#    1
#   </imagegallerysize>
#   <imagelink>
#    https://www.globalgiving.org/pfil/31/pict.jpg
#   </imagelink>
#   <iso3166countrycode>
#    US
#   </iso3166countrycode>
#   <longtermimpact>
#    This project will help to develop a core collection of K-12 books to serve students with disabilities.
#   </longtermimpact>
#   <need>
#    Fewer than 5% of books are produced in formats that are accessible to people who have visual or learning disabilities.  To read other books, more than three million US residents, including one million students, are forced to laboriously scan them into computers.  In particular, K-12 students need accessible textbooks and outside reading material.  Schools are legally required to offer textbooks in these formats, but access is often inadequate and little supplemental reading is made available.
#   </need>
#   <numberofdonations>
#    23
#   </numberofdonations>
#   <organization>
#    <activeprojects>
#     0
#    </activeprojects>
#    <addressline1>
#     480 S. California Ave Suite 201
#    </addressline1>
#    <addressline2>
#    </addressline2>
#    <city>
#     Palo Alto
#    </city>
#    <countries>
#     <country>
#      <iso3166countrycode>
#       BD
#      </iso3166countrycode>
#      <name>
#       Bangladesh
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       GT
#      </iso3166countrycode>
#      <name>
#       Guatemala
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       IN
#      </iso3166countrycode>
#      <name>
#       India
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       US
#      </iso3166countrycode>
#      <name>
#       United States
#      </name>
#     </country>
#    </countries>
#    <country>
#     United States
#    </country>
#    <ein>
#     77-0225904
#    </ein>
#    <id>
#     200
#    </id>
#    <iso3166countrycode>
#     US
#    </iso3166countrycode>
#    <mission>
#     Benetech is a Silicon Valley nonprofit that develops technology projects addressing major social problems in areas such as disability, human rights, literacy and education. Our predecessor nonprofit, Arkenstone, was founded in 1989 to provide reading tools for people with disabilities. It helped 35,000 visually impaired people in 60 countries to live and work independently before the sale of its business operations to a for-profit company in 2000, which led to the launch of Benetech.
#    </mission>
#    <name>
#     Benetech
#    </name>
#    <postal>
#     94306
#    </postal>
#    <state>
#     CA
#    </state>
#    <themes>
#     <theme>
#      <id>
#       edu
#      </id>
#      <name>
#       Education
#      </name>
#     </theme>
#     <theme>
#      <id>
#       rights
#      </id>
#      <name>
#       Human Rights
#      </name>
#     </theme>
#     <theme>
#      <id>
#       tech
#      </id>
#      <name>
#       Technology
#      </name>
#     </theme>
#    </themes>
#    <totalprojects>
#     6
#    </totalprojects>
#    <url>
#     http://www.benetech.org
#    </url>
#   </organization>
#   <progressreportlink>
#    https://www.globalgiving.org/projects/students-with-disabilities/updates/
#   </progressreportlink>
#   <projectlink>
#    https://www.globalgiving.org/projects/students-with-disabilities/
#   </projectlink>
#   <region>
#    North America
#   </region>
#   <remaining>
#    2640.00
#   </remaining>
#   <status>
#    funded
#   </status>
#   <summary>
#    Adding more accessible textbooks and supplemental reading material for K-12 students with visual and learning disabilities to the Bookshare.org online collection.
#   </summary>
#   <themename>
#    Education
#   </themename>
#   <title>
#    Accessible Books for Students with Disabilities
#   </title>
#   <type>
#    project
#   </type>
#  </project>
#  <project>
#   <active>
#    false
#   </active>
#   <activities>
#    CAT hopes to create classrooms where students participate more actively in learning by improve instruction for 750 additional students through working with 25 more teachers in 2004.
#   </activities>
#   <additionaldocumentation>
#    https://www.globalgiving.org/pfil/51/projdoc.doc
#   </additionaldocumentation>
#   <approveddate>
#    2003-06-30T14:03:32-04:00
#   </approveddate>
#   <contactaddress>
#    1421 22nd St., NW
#   </contactaddress>
#   <contactcity>
#    Washington, D.C.
#   </contactcity>
#   <contactcountry>
#    United States
#   </contactcountry>
#   <contactpostal>
#    20037
#   </contactpostal>
#   <contactstate>
#   </contactstate>
#   <contacturl>
#    http://www.artistryinteaching.org
#   </contacturl>
#   <country>
#    United States
#   </country>
#   <funding>
#    0.00
#   </funding>
#   <goal>
#    22000.00
#   </goal>
#   <id>
#    51
#   </id>
#   <image id="0">
#    <imagelink size="small">
#     <url>
#      https://www.globalgiving.org/pfil/51/pict_grid1.jpg
#     </url>
#    </imagelink>
#    <imagelink size="thumbnail">
#     <url>
#      https://www.globalgiving.org/pfil/51/pict_thumbnail.jpg
#     </url>
#    </imagelink>
#    <imagelink size="medium">
#     <url>
#      https://www.globalgiving.org/pfil/51/pict_med.jpg
#     </url>
#    </imagelink>
#    <imagelink size="large">
#     <url>
#      https://www.globalgiving.org/pfil/51/pict_grid7.jpg
#     </url>
#    </imagelink>
#    <imagelink size="extraLarge">
#     <url>
#      https://www.globalgiving.org/pfil/51/pict_large.jpg
#     </url>
#    </imagelink>
#    <imagelink size="original">
#     <url>
#      https://www.globalgiving.org/pfil/51/pict_original.jpg
#     </url>
#    </imagelink>
#    <title>
#     Workshop in the Art of Teaching
#    </title>
#
#   <imagegallerysize>
#    1
#   </imagegallerysize>
#   <imagelink>
#    https://www.globalgiving.org/pfil/51/pict.jpg
#   </imagelink>
#   <iso3166countrycode>
#    US
#   </iso3166countrycode>
#   <longtermimpact>
#    Create an atmosphere where teachers spend less time maintaining discipline and more time teaching, where teachers teach students to think critically and solve problems, and finally, where children feel safe and can focus on learning.
#   </longtermimpact>
#   <need>
#    A child's success in life depends to a great extent on the quality of education the child receives. This is especially true for children living in impoverished communities.  Center for Artistry in Teaching is reengineering the way teachers see themselves and the way they teach - to include their total mind, heart, and body, while incorporating spontaneity, critical thinking, and problem solving. The result is a re-energized educator who engages in the art of teaching.
#   </need>
#   <numberofdonations>
#    0
#   </numberofdonations>
#   <organization>
#    <activeprojects>
#     0
#    </activeprojects>
#    <addressline1>
#     1421 22nd St., NW
#    </addressline1>
#    <addressline2>
#    </addressline2>
#    <city>
#     Washington
#    </city>
#    <countries>
#     <country>
#      <iso3166countrycode>
#       US
#      </iso3166countrycode>
#      <name>
#       United States
#      </name>
#     </country>
#    </countries>
#    <country>
#     United States
#    </country>
#    <id>
#     31
#    </id>
#    <iso3166countrycode>
#     US
#    </iso3166countrycode>
#    <mission>
#     Most teachers teach students what to think. CAT teachers teach students how to think. Through innovative programs for teachers, CAT is leading a teacher-driven movement to reform public schools. By preparing children to learn and strengthening teachers’ skills, CAT is transforming the way teaching and learning take place in US schools.  CAT is at a critical stage in its organizational development, poised to double the number of teachers we reach each year.
#    </mission>
#    <name>
#     Center for Artistry in Teaching (CAT)
#    </name>
#    <postal>
#     20037
#    </postal>
#    <state>
#     DC
#    </state>
#    <themes>
#     <theme>
#      <id>
#       edu
#      </id>
#      <name>
#       Education
#      </name>
#     </theme>
#    </themes>
#    <totalprojects>
#     1
#    </totalprojects>
#    <url>
#     http://www.artistryinteaching.org
#    </url>
#   </organization>
#   <progressreportlink>
#    https://www.globalgiving.org/projects/workshop-in-the-art-of-teaching/updates/
#   </progressreportlink>
#   <projectlink>
#    https://www.globalgiving.org/projects/workshop-in-the-art-of-teaching/
#   </projectlink>
#   <region>
#    North America
#   </region>
#   <remaining>
#    22000.00
#   </remaining>
#   <status>
#    retired
#   </status>
#   <summary>
#    The quality of a child's teachers has an enormous impact on that child's chances for success in life. The Workshop in the Art of Teaching improves the effectiveness of teachers.
#   </summary>
#   <themename>
#    Education
#   </themename>
#   <title>
#    Workshop in the Art of Teaching
#   </title>
#   <type>
#    project
#   </type>
#  </project>
#  <project>
#   <active>
#    false
#   </active>
#   <activities>
#   </activities>
#   <additionaldocumentation>
#    https://www.globalgiving.org/pfil/254/projdoc.doc
#   </additionaldocumentation>
#   <approveddate>
#    2003-08-31T16:00:36-04:00
#   </approveddate>
#   <contactaddress>
#    Village Emporium
#   </contactaddress>
#   <contactaddress2>
#    114 Jefferson Street S.
#   </contactaddress2>
#   <contactcity>
#    Wadena
#   </contactcity>
#   <contactcountry>
#    United States
#   </contactcountry>
#   <contactpostal>
#    56482
#   </contactpostal>
#   <contactstate>
#    Minnesota
#   </contactstate>
#   <contacturl>
#    http://www.q-connections.org
#   </contacturl>
#   <country>
#    United States
#   </country>
#   <funding>
#    0.00
#   </funding>
#   <goal>
#    7000.00
#   </goal>
#   <id>
#    254
#   </id>
#   <image id="0">
#    <imagelink size="small">
#     <url>
#      https://www.globalgiving.org/share/dfltpict.jpg
#     </url>
#    </imagelink>
#    <imagelink size="thumbnail">
#     <url>
#      https://www.globalgiving.org/share/dfltpict.jpg
#     </url>
#    </imagelink>
#    <imagelink size="medium">
#     <url>
#      https://www.globalgiving.org/share/dfltpict.jpg
#     </url>
#    </imagelink>
#    <imagelink size="large">
#     <url>
#      https://www.globalgiving.org/share/dfltpict.jpg
#     </url>
#    </imagelink>
#    <imagelink size="extraLarge">
#     <url>
#      https://www.globalgiving.org/share/dfltpict.jpg
#     </url>
#    </imagelink>
#    <imagelink size="original">
#     <url>
#      https://www.globalgiving.org/share/dfltpict.jpg
#     </url>
#    </imagelink>
#    <title>
#     QC Resource Center for World Development Minnesota
#    </title>
#
#   <imagelink>
#    https://www.globalgiving.org/share/dfltpict.jpg
#   </imagelink>
#   <iso3166countrycode>
#    US
#   </iso3166countrycode>
#   <longtermimpact>
#   </longtermimpact>
#   <need>
#    Education about other cultures, the world economy and developing countries is needed in our society. Access is facilitated where there is a center offering services to a broad range of people and groups. It will recruit volunteers who want to travel to the developing world. The center needs income
#   </need>
#   <numberofdonations>
#    0
#   </numberofdonations>
#   <organization>
#    <activeprojects>
#     0
#    </activeprojects>
#    <addressline1>
#     28503 Ottawa Drive
#    </addressline1>
#    <addressline2>
#    </addressline2>
#    <city>
#     Browerville
#    </city>
#    <countries>
#     <country>
#      <iso3166countrycode>
#       EC
#      </iso3166countrycode>
#      <name>
#       Ecuador
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       GH
#      </iso3166countrycode>
#      <name>
#       Ghana
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       SL
#      </iso3166countrycode>
#      <name>
#       Sierra Leone
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       US
#      </iso3166countrycode>
#      <name>
#       United States
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       ZM
#      </iso3166countrycode>
#      <name>
#       Zambia
#      </name>
#     </country>
#    </countries>
#    <country>
#     United States
#    </country>
#    <ein>
#     41-1983907
#    </ein>
#    <id>
#     181
#    </id>
#    <iso3166countrycode>
#     US
#    </iso3166countrycode>
#    <mission>
#     To help build a more just and sustainable world by creating global partnerships.
# It does this
# -by linking individuals and groups who are seeking global partnerships and opportunities
# -by promoting responsible and meaningful travel and tourism experiences
# - - by facilitating communication and learning through the supply of computers to partners
# - and by providing opportunities for multi-cultural experience
#    </mission>
#    <name>
#     Quantum Connections - Creating Global Partnerships
#    </name>
#    <postal>
#     56438
#    </postal>
#    <state>
#     Minnesota
#    </state>
#    <themes>
#     <theme>
#      <id>
#       ecdev
#      </id>
#      <name>
#       Economic Development
#      </name>
#     </theme>
#     <theme>
#      <id>
#       edu
#      </id>
#      <name>
#       Education
#      </name>
#     </theme>
#     <theme>
#      <id>
#       env
#      </id>
#      <name>
#       Environment
#      </name>
#     </theme>
#    </themes>
#    <totalprojects>
#     5
#    </totalprojects>
#    <url>
#     http://www.q-connections.org
#    </url>
#   </organization>
#   <progressreportlink>
#    https://www.globalgiving.org/projects/qc-resource-center-for-world-development-minnesota/updates/
#   </progressreportlink>
#   <projectlink>
#    https://www.globalgiving.org/projects/qc-resource-center-for-world-development-minnesota/
#   </projectlink>
#   <region>
#    North America
#   </region>
#   <remaining>
#    7000.00
#   </remaining>
#   <status>
#    retired
#   </status>
#   <summary>
#    A center, with coffee house, focussed on world development and on justice and peace. Resources available to schoolsand colleges  in central Minnesota to enable people to Think Globally, Act Locally.
#   </summary>
#   <themename>
#    Economic Development
#   </themename>
#   <title>
#    QC Resource Center for World Development Minnesota
#   </title>
#   <type>
#    project
#   </type>
#  </project>
#  <project>
#   <active>
#    false
#   </active>
#   <activities>
#    It ensures that more GlobalGiving projects receive the funding necessary to begin implementation.
#   </activities>
#   <additionaldocumentation>
#    https://www.globalgiving.org/pfil/284/projdoc.doc
#   </additionaldocumentation>
#   <approveddate>
#    2003-10-14T13:08:05-04:00
#   </approveddate>
#   <contactaddress>
#    1816 12th St NW, 3rd floor
#   </contactaddress>
#   <contactcity>
#    Washington
#   </contactcity>
#   <contactcountry>
#    United States
#   </contactcountry>
#   <contactpostal>
#    20009
#   </contactpostal>
#   <contactstate>
#    DC
#   </contactstate>
#   <contacturl>
#    http://www.globalgiving.com
#   </contacturl>
#   <country>
#    United States
#   </country>
#   <funding>
#    7344.70
#   </funding>
#   <goal>
#    100000.00
#   </goal>
#   <id>
#    284
#   </id>
#   <image id="0">
#    <imagelink size="small">
#     <url>
#      https://www.globalgiving.org/pfil/284/pict_grid1.jpg
#     </url>
#    </imagelink>
#    <imagelink size="thumbnail">
#     <url>
#      https://www.globalgiving.org/pfil/284/pict_thumbnail.jpg
#     </url>
#    </imagelink>
#    <imagelink size="medium">
#     <url>
#      https://www.globalgiving.org/pfil/284/pict_med.jpg
#     </url>
#    </imagelink>
#    <imagelink size="large">
#     <url>
#      https://www.globalgiving.org/pfil/284/pict_grid7.jpg
#     </url>
#    </imagelink>
#    <imagelink size="extraLarge">
#     <url>
#      https://www.globalgiving.org/pfil/284/pict_large.jpg
#     </url>
#    </imagelink>
#    <imagelink size="original">
#     <url>
#      https://www.globalgiving.org/pfil/284/pict_original.jpg
#     </url>
#    </imagelink>
#    <title>
#     GlobalGiving Matching Fund
#    </title>
#
#   <imagegallerysize>
#    1
#   </imagegallerysize>
#   <imagelink>
#    https://www.globalgiving.org/pfil/284/pict.jpg
#   </imagelink>
#   <iso3166countrycode>
#    US
#   </iso3166countrycode>
#   <longtermimpact>
#    The goal of GlobalGiving's matching fund is to provide donors with another high-impact giving opportunity without making them have to specify a project.
#   </longtermimpact>
#   <need>
#    The GlobalGiving matching fund uses donations to support those projects that are closest to reaching their funding objective.  It is a terrific option for those donors in a hurry or those that can't make up their mind.
#   </need>
#   <numberofdonations>
#    6
#   </numberofdonations>
#   <organization>
#    <activeprojects>
#     31
#    </activeprojects>
#    <addressline1>
#     1110 Vermont Avenue NW
#    </addressline1>
#    <addressline2>
#     Suite 550
#    </addressline2>
#    <city>
#     Washington
#    </city>
#    <countries>
#     <country>
#      <iso3166countrycode>
#       AF
#      </iso3166countrycode>
#      <name>
#       Afghanistan
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       BD
#      </iso3166countrycode>
#      <name>
#       Bangladesh
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       BR
#      </iso3166countrycode>
#      <name>
#       Brazil
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       BF
#      </iso3166countrycode>
#      <name>
#       Burkina Faso
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       KH
#      </iso3166countrycode>
#      <name>
#       Cambodia
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       TD
#      </iso3166countrycode>
#      <name>
#       Chad
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       CL
#      </iso3166countrycode>
#      <name>
#       Chile
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       CN
#      </iso3166countrycode>
#      <name>
#       China
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       CR
#      </iso3166countrycode>
#      <name>
#       Costa Rica
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       CD
#      </iso3166countrycode>
#      <name>
#       Congo, Democratic Republic of the
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       DJ
#      </iso3166countrycode>
#      <name>
#       Djibouti
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       ET
#      </iso3166countrycode>
#      <name>
#       Ethiopia
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       FI
#      </iso3166countrycode>
#      <name>
#       Finland
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       GT
#      </iso3166countrycode>
#      <name>
#       Guatemala
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       GY
#      </iso3166countrycode>
#      <name>
#       Guyana
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       HT
#      </iso3166countrycode>
#      <name>
#       Haiti
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       HK
#      </iso3166countrycode>
#      <name>
#       Hong Kong
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       IN
#      </iso3166countrycode>
#      <name>
#       India
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       ID
#      </iso3166countrycode>
#      <name>
#       Indonesia
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       IT
#      </iso3166countrycode>
#      <name>
#       Italy
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       JP
#      </iso3166countrycode>
#      <name>
#       Japan
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       KE
#      </iso3166countrycode>
#      <name>
#       Kenya
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       MW
#      </iso3166countrycode>
#      <name>
#       Malawi
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       MY
#      </iso3166countrycode>
#      <name>
#       Malaysia
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       ML
#      </iso3166countrycode>
#      <name>
#       Mali
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       MR
#      </iso3166countrycode>
#      <name>
#       Mauritania
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       MA
#      </iso3166countrycode>
#      <name>
#       Morocco
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       MM
#      </iso3166countrycode>
#      <name>
#       Myanmar
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       NA
#      </iso3166countrycode>
#      <name>
#       Namibia
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       NP
#      </iso3166countrycode>
#      <name>
#       Nepal
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       NZ
#      </iso3166countrycode>
#      <name>
#       New Zealand
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       NE
#      </iso3166countrycode>
#      <name>
#       Niger
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       PK
#      </iso3166countrycode>
#      <name>
#       Pakistan
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       PY
#      </iso3166countrycode>
#      <name>
#       Paraguay
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       PH
#      </iso3166countrycode>
#      <name>
#       Philippines
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       RW
#      </iso3166countrycode>
#      <name>
#       Rwanda
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       SN
#      </iso3166countrycode>
#      <name>
#       Senegal
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       SL
#      </iso3166countrycode>
#      <name>
#       Sierra Leone
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       SO
#      </iso3166countrycode>
#      <name>
#       Somalia
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       ZA
#      </iso3166countrycode>
#      <name>
#       South Africa
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       KR
#      </iso3166countrycode>
#      <name>
#       South Korea
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       ES
#      </iso3166countrycode>
#      <name>
#       Spain
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       LK
#      </iso3166countrycode>
#      <name>
#       Sri Lanka
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       SD
#      </iso3166countrycode>
#      <name>
#       Sudan
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       TZ
#      </iso3166countrycode>
#      <name>
#       Tanzania, United Republic of
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       TH
#      </iso3166countrycode>
#      <name>
#       Thailand
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       TR
#      </iso3166countrycode>
#      <name>
#       Turkey
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       UG
#      </iso3166countrycode>
#      <name>
#       Uganda
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       GB
#      </iso3166countrycode>
#      <name>
#       United Kingdom
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       US
#      </iso3166countrycode>
#      <name>
#       United States
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       VN
#      </iso3166countrycode>
#      <name>
#       Vietnam
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       WS
#      </iso3166countrycode>
#      <name>
#       Samoa
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       ZM
#      </iso3166countrycode>
#      <name>
#       Zambia
#      </name>
#     </country>
#    </countries>
#    <country>
#     United States
#    </country>
#    <ein>
#     30-0108263
#    </ein>
#    <id>
#     189
#    </id>
#    <iso3166countrycode>
#     US
#    </iso3166countrycode>
#    <logourl>
#     https://dpqe0zkrjo0ak.cloudfront.net/pfil/organ/189/orglogo.jpg
#    </logourl>
#    <mission>
#     Our mission is to build an efficient, open, thriving marketplace that connects people who have community and world-changing ideas with people who can support them.
#    </mission>
#    <name>
#     GlobalGiving
#    </name>
#    <postal>
#     20005
#    </postal>
#    <state>
#     D.C.
#    </state>
#    <themes>
#     <theme>
#      <id>
#       animals
#      </id>
#      <name>
#       Animals
#      </name>
#     </theme>
#     <theme>
#      <id>
#       children
#      </id>
#      <name>
#       Children
#      </name>
#     </theme>
#     <theme>
#      <id>
#       democ
#      </id>
#      <name>
#       Democracy and Governance
#      </name>
#     </theme>
#     <theme>
#      <id>
#       disaster
#      </id>
#      <name>
#       Disaster Recovery
#      </name>
#     </theme>
#     <theme>
#      <id>
#       ecdev
#      </id>
#      <name>
#       Economic Development
#      </name>
#     </theme>
#     <theme>
#      <id>
#       edu
#      </id>
#      <name>
#       Education
#      </name>
#     </theme>
#     <theme>
#      <id>
#       env
#      </id>
#      <name>
#       Environment
#      </name>
#     </theme>
#     <theme>
#      <id>
#       finance
#      </id>
#      <name>
#       Microfinance
#      </name>
#     </theme>
#     <theme>
#      <id>
#       gender
#      </id>
#      <name>
#       Women and Girls
#      </name>
#     </theme>
#     <theme>
#      <id>
#       health
#      </id>
#      <name>
#       Health
#      </name>
#     </theme>
#     <theme>
#      <id>
#       rights
#      </id>
#      <name>
#       Human Rights
#      </name>
#     </theme>
#     <theme>
#      <id>
#       tech
#      </id>
#      <name>
#       Technology
#      </name>
#     </theme>
#     <theme>
#      <id>
#       hunger
#      </id>
#      <name>
#       Hunger
#      </name>
#     </theme>
#    </themes>
#    <totalprojects>
#     96
#    </totalprojects>
#    <url>
#     https://www.globalgiving.org
#    </url>
#   </organization>
#   <progressreportlink>
#    https://www.globalgiving.org/projects/globalgiving-matching-fund/updates/
#   </progressreportlink>
#   <projectlink>
#    https://www.globalgiving.org/projects/globalgiving-matching-fund/
#   </projectlink>
#   <region>
#    North America
#   </region>
#   <remaining>
#    92655.30
#   </remaining>
#   <status>
#    retired
#   </status>
#   <summary>
#    GlobalGiving's matching fund allows donors to contribute to a general pool that will allow projects that are almost fully funded, reach their budget target.
#   </summary>
#   <themename>
#    Economic Development
#   </themename>
#   <title>
#    GlobalGiving Matching Fund
#   </title>
#   <type>
#    project
#   </type>
#  </project>
#  <project>
#   <active>
#    false
#   </active>
#   <activities>
#    To purchase and scan 100 books that have been requested by teachers and parents. Ten of these will be textbooks that will be proofread for perfect text accuracy. All 100 will be shared nationwide through the Bookshare.org online collection.
#   </activities>
#   <additionaldocumentation>
#    https://www.globalgiving.org/pfil/367/projdoc.doc
#   </additionaldocumentation>
#   <approveddate>
#    2004-06-01T12:43:32-04:00
#   </approveddate>
#   <contactaddress>
#    480 S. California Ave
#   </contactaddress>
#   <contactaddress2>
#    Suite 201
#   </contactaddress2>
#   <contactcity>
#    Palo Alto
#   </contactcity>
#   <contactcountry>
#    United States
#   </contactcountry>
#   <contactpostal>
#    94306
#   </contactpostal>
#   <contactstate>
#    California
#   </contactstate>
#   <contacturl>
#    http://www.bookshare.org
#   </contacturl>
#   <country>
#    United States
#   </country>
#   <funding>
#    745.00
#   </funding>
#   <goal>
#    5060.00
#   </goal>
#   <id>
#    367
#   </id>
#   <image id="0">
#    <imagelink size="small">
#     <url>
#      https://www.globalgiving.org/pfil/367/pict_grid1.jpg
#     </url>
#    </imagelink>
#    <imagelink size="thumbnail">
#     <url>
#      https://www.globalgiving.org/pfil/367/pict_thumbnail.jpg
#     </url>
#    </imagelink>
#    <imagelink size="medium">
#     <url>
#      https://www.globalgiving.org/pfil/367/pict_med.jpg
#     </url>
#    </imagelink>
#    <imagelink size="large">
#     <url>
#      https://www.globalgiving.org/pfil/367/pict_grid7.jpg
#     </url>
#    </imagelink>
#    <imagelink size="extraLarge">
#     <url>
#      https://www.globalgiving.org/pfil/367/pict_large.jpg
#     </url>
#    </imagelink>
#    <imagelink size="original">
#     <url>
#      https://www.globalgiving.org/pfil/367/pict_original.jpg
#     </url>
#    </imagelink>
#    <title>
#     Accessible Books for Students with Disabilities
#    </title>
#
#   <imagegallerysize>
#    3
#   </imagegallerysize>
#   <imagelink>
#    https://www.globalgiving.org/pfil/367/pict.jpg
#   </imagelink>
#   <iso3166countrycode>
#    US
#   </iso3166countrycode>
#   <longtermimpact>
#    This project will help to develop a core collection of K-12 books to serve students with disabilities.
#   </longtermimpact>
#   <need>
#    Fewer than 5% of books are produced in formats that are accessible to people who have visual or learning disabilities.  To read other books, more than three million US residents, including one million students, are forced to laboriously scan them into computers.  In particular, K-12 students need accessible textbooks and outside reading material.  Schools are legally required to offer textbooks in these formats, but access is often inadequate and little supplemental reading is made available.
#   </need>
#   <numberofdonations>
#    1
#   </numberofdonations>
#   <organization>
#    <activeprojects>
#     0
#    </activeprojects>
#    <addressline1>
#     480 S. California Ave Suite 201
#    </addressline1>
#    <addressline2>
#    </addressline2>
#    <city>
#     Palo Alto
#    </city>
#    <countries>
#     <country>
#      <iso3166countrycode>
#       BD
#      </iso3166countrycode>
#      <name>
#       Bangladesh
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       GT
#      </iso3166countrycode>
#      <name>
#       Guatemala
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       IN
#      </iso3166countrycode>
#      <name>
#       India
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       US
#      </iso3166countrycode>
#      <name>
#       United States
#      </name>
#     </country>
#    </countries>
#    <country>
#     United States
#    </country>
#    <ein>
#     77-0225904
#    </ein>
#    <id>
#     200
#    </id>
#    <iso3166countrycode>
#     US
#    </iso3166countrycode>
#    <mission>
#     Benetech is a Silicon Valley nonprofit that develops technology projects addressing major social problems in areas such as disability, human rights, literacy and education. Our predecessor nonprofit, Arkenstone, was founded in 1989 to provide reading tools for people with disabilities. It helped 35,000 visually impaired people in 60 countries to live and work independently before the sale of its business operations to a for-profit company in 2000, which led to the launch of Benetech.
#    </mission>
#    <name>
#     Benetech
#    </name>
#    <postal>
#     94306
#    </postal>
#    <state>
#     CA
#    </state>
#    <themes>
#     <theme>
#      <id>
#       edu
#      </id>
#      <name>
#       Education
#      </name>
#     </theme>
#     <theme>
#      <id>
#       rights
#      </id>
#      <name>
#       Human Rights
#      </name>
#     </theme>
#     <theme>
#      <id>
#       tech
#      </id>
#      <name>
#       Technology
#      </name>
#     </theme>
#    </themes>
#    <totalprojects>
#     6
#    </totalprojects>
#    <url>
#     http://www.benetech.org
#    </url>
#   </organization>
#   <progressreportlink>
#    https://www.globalgiving.org/projects/students-with-disabilities-1/updates/
#   </progressreportlink>
#   <projectlink>
#    https://www.globalgiving.org/projects/students-with-disabilities-1/
#   </projectlink>
#   <region>
#    North America
#   </region>
#   <remaining>
#    4315.00
#   </remaining>
#   <status>
#    funded
#   </status>
#   <summary>
#    Adding more accessible textbooks and supplemental reading material for K-12 students with visual and learning disabilities to the Bookshare.org online collection.
#   </summary>
#   <themename>
#    Education
#   </themename>
#   <title>
#    Accessible Books for Students with Disabilities
#   </title>
#   <type>
#    project
#   </type>
#  </project>
#  <project>
#   <active>
#    true
#   </active>
#   <activities>
#    This fund ensures that more GlobalGiving projects receive the funding necessary to begin implementation.
#   </activities>
#   <additionaldocumentation>
#    https://www.globalgiving.org/pfil/554/projdoc.pdf
#   </additionaldocumentation>
#   <approveddate>
#    2004-06-01T12:45:32-04:00
#   </approveddate>
#   <contactaddress>
#    1023, 15th Street, Suite 1200
#   </contactaddress>
#   <contactcity>
#    Washington
#   </contactcity>
#   <contactcountry>
#    United States
#   </contactcountry>
#   <contactname>
#    Britt Lake
#   </contactname>
#   <contactpostal>
#    20005
#   </contactpostal>
#   <contactstate>
#    D.C.
#   </contactstate>
#   <contacturl>
#    http://www.globalgiving.org
#   </contacturl>
#   <country>
#    United States
#   </country>
#   <donationoptions>
#    <donationoption>
#     <amount>
#      15
#     </amount>
#     <description>
#      Matching funds and incentives for GlobalGiving projects
#     </description>
#    </donationoption>
#    <donationoption>
#     <amount>
#      50
#     </amount>
#     <description>
#      Matching funds and incentives for GlobalGiving projects
#     </description>
#    </donationoption>
#    <donationoption>
#     <amount>
#      150
#     </amount>
#     <description>
#      Matching funds and incentives for GlobalGiving projects
#     </description>
#    </donationoption>
#    <donationoption>
#     <amount>
#      500
#     </amount>
#     <description>
#      Matching funds and incentives for GlobalGiving projects
#     </description>
#    </donationoption>
#    <donationoption>
#     <amount>
#      1000
#     </amount>
#     <description>
#      Matching funds and incentives for GlobalGiving projects
#     </description>
#    </donationoption>
#   </donationoptions>
#   <funding>
#    1553964.51
#   </funding>
#   <goal>
#    2000000.00
#   </goal>
#   <id>
#    554
#   </id>
#   <image id="0">
#    <imagelink size="small">
#     <url>
#      https://www.globalgiving.org/pfil/554/pict_grid1.jpg
#     </url>
#    </imagelink>
#    <imagelink size="thumbnail">
#     <url>
#      https://www.globalgiving.org/pfil/554/pict_thumbnail.jpg
#     </url>
#    </imagelink>
#    <imagelink size="medium">
#     <url>
#      https://www.globalgiving.org/pfil/554/pict_med.jpg
#     </url>
#    </imagelink>
#    <imagelink size="large">
#     <url>
#      https://www.globalgiving.org/pfil/554/pict_grid7.jpg
#     </url>
#    </imagelink>
#    <imagelink size="extraLarge">
#     <url>
#      https://www.globalgiving.org/pfil/554/pict_large.jpg
#     </url>
#    </imagelink>
#    <imagelink size="original">
#     <url>
#      https://www.globalgiving.org/pfil/554/pict_original.jpg
#     </url>
#    </imagelink>
#    <title>
#     GlobalGiving Fund
#    </title>
#
#   <imagegallerysize>
#    1
#   </imagegallerysize>
#   <imagelink>
#    https://www.globalgiving.org/pfil/554/pict.jpg
#   </imagelink>
#   <iso3166countrycode>
#    US
#   </iso3166countrycode>
#   <latitude>
#    38.92020034790039
#   </latitude>
#   <longtermimpact>
#    Since 2008, every dollar that has been donated to this fund has resulted in an average of $6 reaching a project through an incentive campaign. This means that your donation generates 6x impact when supporting the GlobalGiving Fund.
#   </longtermimpact>
#   <longitude>
#    -77.03750610351562
#   </longitude>
#   <need>
#    This fund will support all the projects on the GlobalGiving website.  Donations will be used to provide incentives like matching funds and bonuses during campaigns and bonus days for existing and new projects. A portion of the fund may also go to support GlobalGiving's operations so that we can serve more organizations and projects.
#   </need>
#   <numberofdonations>
#    28316
#   </numberofdonations>
#   <organization>
#    <activeprojects>
#     31
#    </activeprojects>
#    <addressline1>
#     1110 Vermont Avenue NW
#    </addressline1>
#    <addressline2>
#     Suite 550
#    </addressline2>
#    <city>
#     Washington
#    </city>
#    <countries>
#     <country>
#      <iso3166countrycode>
#       AF
#      </iso3166countrycode>
#      <name>
#       Afghanistan
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       BD
#      </iso3166countrycode>
#      <name>
#       Bangladesh
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       BR
#      </iso3166countrycode>
#      <name>
#       Brazil
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       BF
#      </iso3166countrycode>
#      <name>
#       Burkina Faso
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       KH
#      </iso3166countrycode>
#      <name>
#       Cambodia
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       TD
#      </iso3166countrycode>
#      <name>
#       Chad
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       CL
#      </iso3166countrycode>
#      <name>
#       Chile
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       CN
#      </iso3166countrycode>
#      <name>
#       China
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       CR
#      </iso3166countrycode>
#      <name>
#       Costa Rica
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       CD
#      </iso3166countrycode>
#      <name>
#       Congo, Democratic Republic of the
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       DJ
#      </iso3166countrycode>
#      <name>
#       Djibouti
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       ET
#      </iso3166countrycode>
#      <name>
#       Ethiopia
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       FI
#      </iso3166countrycode>
#      <name>
#       Finland
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       GT
#      </iso3166countrycode>
#      <name>
#       Guatemala
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       GY
#      </iso3166countrycode>
#      <name>
#       Guyana
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       HT
#      </iso3166countrycode>
#      <name>
#       Haiti
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       HK
#      </iso3166countrycode>
#      <name>
#       Hong Kong
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       IN
#      </iso3166countrycode>
#      <name>
#       India
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       ID
#      </iso3166countrycode>
#      <name>
#       Indonesia
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       IT
#      </iso3166countrycode>
#      <name>
#       Italy
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       JP
#      </iso3166countrycode>
#      <name>
#       Japan
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       KE
#      </iso3166countrycode>
#      <name>
#       Kenya
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       MW
#      </iso3166countrycode>
#      <name>
#       Malawi
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       MY
#      </iso3166countrycode>
#      <name>
#       Malaysia
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       ML
#      </iso3166countrycode>
#      <name>
#       Mali
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       MR
#      </iso3166countrycode>
#      <name>
#       Mauritania
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       MA
#      </iso3166countrycode>
#      <name>
#       Morocco
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       MM
#      </iso3166countrycode>
#      <name>
#       Myanmar
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       NA
#      </iso3166countrycode>
#      <name>
#       Namibia
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       NP
#      </iso3166countrycode>
#      <name>
#       Nepal
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       NZ
#      </iso3166countrycode>
#      <name>
#       New Zealand
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       NE
#      </iso3166countrycode>
#      <name>
#       Niger
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       PK
#      </iso3166countrycode>
#      <name>
#       Pakistan
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       PY
#      </iso3166countrycode>
#      <name>
#       Paraguay
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       PH
#      </iso3166countrycode>
#      <name>
#       Philippines
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       RW
# ...
#   </contactcountry>
#   <contactpostal>
#    99712
#   </contactpostal>
#   <contactstate>
#    AK
#   </contactstate>
#   <contacturl>
#    http://www.GUTENBERG.NET
#   </contacturl>
#   <country>
#    United States
#   </country>
#   <funding>
#    0.00
#   </funding>
#   <goal>
#    50000.00
#   </goal>
#   <id>
#    596
#   </id>
#   <image id="0">
#    <imagelink size="small">
#     <url>
#      https://www.globalgiving.org/pfil/596/pict_grid1.jpg
#     </url>
#    </imagelink>
#    <imagelink size="thumbnail">
#     <url>
#      https://www.globalgiving.org/pfil/596/pict_thumbnail.jpg
#     </url>
#    </imagelink>
#    <imagelink size="medium">
#     <url>
#      https://www.globalgiving.org/pfil/596/pict_med.jpg
#     </url>
#    </imagelink>
#    <imagelink size="large">
#     <url>
#      https://www.globalgiving.org/pfil/596/pict_grid7.jpg
#     </url>
#    </imagelink>
#    <imagelink size="extraLarge">
#     <url>
#      https://www.globalgiving.org/pfil/596/pict_large.jpg
#     </url>
#    </imagelink>
#    <imagelink size="original">
#     <url>
#      https://www.globalgiving.org/pfil/596/pict_original.jpg
#     </url>
#    </imagelink>
#    <title>
#     Project Gutenberg
#    </title>
#
#   <imagegallerysize>
#    1
#   </imagegallerysize>
#   <imagelink>
#    https://www.globalgiving.org/pfil/596/pict.jpg
#   </imagelink>
#   <iso3166countrycode>
#    US
#   </iso3166countrycode>
#   <longtermimpact>
#    Ten million eBooks into the hands of people who can in turn give away free copies of the DVD or individual eBooks. Once Project Gutenberg creates a new eBook, we catalogue it, place it on several servers, and announce it to the world.
#   </longtermimpact>
#   <need>
#    Nearly all funds go directly to the support of volunteers or the distribution of eBooks. The Project Gutenberg mission is to make literature available free of charge or at the lowest possible price. Billions of free eBooks have been given away on CD and DVD, in addition to millions of downloads per month via the Internet.
#   </need>
#   <numberofdonations>
#    18
#   </numberofdonations>
#   <organization>
#    <activeprojects>
#     0
#    </activeprojects>
#    <addressline1>
#     4557 Melan Dr. S.
#    </addressline1>
#    <addressline2>
#    </addressline2>
#    <city>
#     Fairbanks
#    </city>
#    <countries>
#     <country>
#      <iso3166countrycode>
#       US
#      </iso3166countrycode>
#      <name>
#       United States
#      </name>
#     </country>
#    </countries>
#    <country>
#     United States
#    </country>
#    <ein>
#     64-6221541
#    </ein>
#    <id>
#     205
#    </id>
#    <iso3166countrycode>
#     US
#    </iso3166countrycode>
#    <logourl>
#     https://dpqe0zkrjo0ak.cloudfront.net/pfil/organ/205/orglogo.gif
#    </logourl>
#    <mission>
#     To generate and distribute electronic literature.
#    </mission>
#    <name>
#     The Project Gutenberg Literary Archive Foundation
#    </name>
#    <postal>
#     99712
#    </postal>
#    <state>
#     AK
#    </state>
#    <themes>
#     <theme>
#      <id>
#       edu
#      </id>
#      <name>
#       Education
#      </name>
#     </theme>
#    </themes>
#    <totalprojects>
#     1
#    </totalprojects>
#    <url>
#     http://www.GUTENBERG.NET
#    </url>
#   </organization>
#   <progressreportlink>
#    https://www.globalgiving.org/projects/project-gutenberg/updates/
#   </progressreportlink>
#   <projectlink>
#    https://www.globalgiving.org/projects/project-gutenberg/
#   </projectlink>
#   <region>
#    North America
#   </region>
#   <remaining>
#    50000.00
#   </remaining>
#   <status>
#    retired
#   </status>
#   <summary>
#    Free electronic literature (eBooks) in many formats and languages which are distributed through a network of sites worldwide. The eBooks are produced by thousands of volunteers.
#   </summary>
#   <themename>
#    Education
#   </themename>
#   <title>
#    Project Gutenberg
#   </title>
#   <type>
#    project
#   </type>
#  </project>
#  <project>
#   <active>
#    false
#   </active>
#   <activities>
#    Our worldwide mapmaker network is involved in the updating process. With their help, we will design new/revised Icons, create digital icon fonts, translate definitions and provide multi-lingual database/digital posters and public awareness materials.
#   </activities>
#   <additionaldocumentation>
#    https://www.globalgiving.org/pfil/603/projdoc.pdf
#   </additionaldocumentation>
#   <approveddate>
#    2006-09-01T09:16:53-04:00
#   </approveddate>
#   <contactaddress>
#    175 Rivington St. #1D (mailing)
#   </contactaddress>
#   <contactaddress2>
#    220A East 4th Street (location)
#   </contactaddress2>
#   <contactcity>
#    New York
#   </contactcity>
#   <contactcountry>
#    United States
#   </contactcountry>
#   <contactname>
#    Wendy E. Brawer
#   </contactname>
#   <contactpostal>
#    10009
#   </contactpostal>
#   <contactstate>
#    NY
#   </contactstate>
#   <contacttitle>
#    Founding Director &amp; Secretary
#   </contacttitle>
#   <contacturl>
#    http://www.greenmap.org
#   </contacturl>
#   <country>
#    United States
#   </country>
#   <donationoptions>
#    <donationoption>
#     <amount>
#      10
#     </amount>
#     <description>
#      Equips 2 developing world Green Map projects.
#     </description>
#    </donationoption>
#    <donationoption>
#     <amount>
#      25
#     </amount>
#     <description>
#      Provides teacher-training workshop with Green Map-making resources.
#     </description>
#    </donationoption>
#    <donationoption>
#     <amount>
#      50
#     </amount>
#     <description>
#      Provides hundreds with digital Icon poster in their local language.
#     </description>
#    </donationoption>
#   </donationoptions>
#   <funding>
#    268.00
#   </funding>
#   <goal>
#    27500.00
#   </goal>
#   <id>
#    603
#   </id>
#   <image id="0">
#    <imagelink size="small">
#     <url>
#      https://www.globalgiving.org/pfil/603/pict_grid1.jpg
#     </url>
#    </imagelink>
#    <imagelink size="thumbnail">
#     <url>
#      https://www.globalgiving.org/pfil/603/pict_thumbnail.jpg
#     </url>
#    </imagelink>
#    <imagelink size="medium">
#     <url>
#      https://www.globalgiving.org/pfil/603/pict_med.jpg
#     </url>
#    </imagelink>
#    <imagelink size="large">
#     <url>
#      https://www.globalgiving.org/pfil/603/pict_grid7.jpg
#     </url>
#    </imagelink>
#    <imagelink size="extraLarge">
#     <url>
#      https://www.globalgiving.org/pfil/603/pict_large.jpg
#     </url>
#    </imagelink>
#    <imagelink size="original">
#     <url>
#      https://www.globalgiving.org/pfil/603/pict_original.jpg
#     </url>
#    </imagelink>
#    <title>
#     Icons for Mapping Community Sustainability
#    </title>
#
#   <imagegallerysize>
#    4
#   </imagegallerysize>
#   <imagelink>
#    https://www.globalgiving.org/pfil/603/pict.jpg
#   </imagelink>
#   <iso3166countrycode>
#    US
#   </iso3166countrycode>
#   <latitude>
#    40.72618865966797
#   </latitude>
#   <longtermimpact>
#    Updated Icons will extend our ability to spur local action for a greener future, benefiting many more communities. We will distribute Green Map Icon resources in both printed and digital formats, making extra effort to reach under-served communities.
#   </longtermimpact>
#   <longitude>
#    -73.9795913696289
#   </longitude>
#   <need>
#    Green Map is updating its award-winning Icons. The world’s only universal iconography for use on maps, these 125 symbols are already helping more than 400 communities in 50 countries highlight sustainable living resources and address ecological and cultural issues on locally-made Green Maps. Update process is collaborative, and will result in a more current and effective shared set of Icons, reflecting the diversity of all participating communities, today and in the future.
#   </need>
#   <numberofdonations>
#    16
#   </numberofdonations>
#   <organization>
#    <activeprojects>
#     2
#    </activeprojects>
#    <addressline1>
#     175 Rivington #1D
#    </addressline1>
#    <addressline2>
#    </addressline2>
#    <city>
#     New York
#    </city>
#    <countries>
#     <country>
#      <iso3166countrycode>
#       AL
#      </iso3166countrycode>
#      <name>
#       Albania
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       AU
#      </iso3166countrycode>
#      <name>
#       Australia
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       AT
#      </iso3166countrycode>
#      <name>
#       Austria
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       BE
#      </iso3166countrycode>
#      <name>
#       Belgium
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       BA
#      </iso3166countrycode>
#      <name>
#       Bosnia and Herzegovina
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       BR
#      </iso3166countrycode>
#      <name>
#       Brazil
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       CA
#      </iso3166countrycode>
#      <name>
#       Canada
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       CN
#      </iso3166countrycode>
#      <name>
#       China
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       CO
#      </iso3166countrycode>
#      <name>
#       Colombia
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       CU
#      </iso3166countrycode>
#      <name>
#       Cuba
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       CZ
#      </iso3166countrycode>
#      <name>
#       Czech Republic
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       DK
#      </iso3166countrycode>
#      <name>
#       Denmark
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       EE
#      </iso3166countrycode>
#      <name>
#       Estonia
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       FI
#      </iso3166countrycode>
#      <name>
#       Finland
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       FR
#      </iso3166countrycode>
#      <name>
#       France
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       DE
#      </iso3166countrycode>
#      <name>
#       Germany
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       HK
#      </iso3166countrycode>
#      <name>
#       Hong Kong
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       HU
#      </iso3166countrycode>
#      <name>
#       Hungary
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       IS
#      </iso3166countrycode>
#      <name>
#       Iceland
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       IN
#      </iso3166countrycode>
#      <name>
#       India
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       ID
#      </iso3166countrycode>
#      <name>
#       Indonesia
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       IE
#      </iso3166countrycode>
#      <name>
#       Ireland
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       IL
#      </iso3166countrycode>
#      <name>
#       Israel
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       IT
#      </iso3166countrycode>
#      <name>
#       Italy
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       JP
#      </iso3166countrycode>
#      <name>
#       Japan
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       LV
#      </iso3166countrycode>
#      <name>
#       Latvia
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       LB
#      </iso3166countrycode>
#      <name>
#       Lebanon
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       LT
#      </iso3166countrycode>
#      <name>
#       Lithuania
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       MX
#      </iso3166countrycode>
#      <name>
#       Mexico
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       NL
#      </iso3166countrycode>
#      <name>
#       Netherlands
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       NG
#      </iso3166countrycode>
#      <name>
#       Nigeria
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       NO
#      </iso3166countrycode>
#      <name>
#       Norway
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       PR
#      </iso3166countrycode>
#      <name>
#       Puerto Rico
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       RO
#      </iso3166countrycode>
#      <name>
#       Romania
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       SG
#      </iso3166countrycode>
#      <name>
#       Singapore
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       ZA
#      </iso3166countrycode>
#      <name>
#       South Africa
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       KR
#      </iso3166countrycode>
#      <name>
#       South Korea
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       ES
#      </iso3166countrycode>
#      <name>
#       Spain
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       SE
#      </iso3166countrycode>
#      <name>
#       Sweden
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       CH
#      </iso3166countrycode>
#      <name>
#       Switzerland
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       TW
#      </iso3166countrycode>
#      <name>
#       Taiwan
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       TH
#      </iso3166countrycode>
#      <name>
#       Thailand
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       GM
#      </iso3166countrycode>
#      <name>
#       Gambia, The
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       UG
#      </iso3166countrycode>
#      <name>
#       Uganda
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       AE
#      </iso3166countrycode>
#      <name>
#       United Arab Emirates
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       GB
#      </iso3166countrycode>
#      <name>
#       United Kingdom
#      </name>
#     </country>
#     <country>
#      <iso3166countrycode>
#       US
#      </iso3166countrycode>
#      <name>
#       United States
#      </name>
#     </country>
#    </countries>
#    <country>
#     United States
#    </country>
#    <ein>
#     13-4062364
#    </ein>
#    <id>
#     209
#    </id>
#    <iso3166countrycode>
#     US
#    </iso3166countrycode>
#    <logourl>
#     https://dpqe0zkrjo0ak.cloudfront.net/pfil/organ/209/orglogo.jpg
#    </logourl>
#    <mission>
#     Engaging communities worldwide to chart a sustainable future - for all of us!
#
# We empower a diverse perspective-changing movement mapping local natural, social and cultural resources in 950+ diverse cities, villages and neighborhoods in over 65 countries. Developing local sustainability networks since 1995, Green Map System expands the demand for healthy, green choices with our adaptable, experiential and interactive mapmaking resources and universal icons, multilingual websites, workshops and regional hubs.
#    </mission>
#    <name>
#     Green Map System
#    </name>
#    <postal>
#     10002
#    </postal>
#    <state>
#     NY
#    </state>
#    <themes>
#     <theme>
#      <id>
#       climate
#      </id>
#      <name>
#       Climate Change
#      </name>
#     </theme>
#     <theme>
#      <id>
#       ecdev
#      </id>
#      <name>
#       Economic Development
#      </name>
#     </theme>
#     <theme>
#      <id>
#       env
#      </id>
#      <name>
#       Environment
#      </name>
#     </theme>
#     <theme>
#      <id>
#       tech
#      </id>
#      <name>
#       Technology
#      </name>
#     </theme>
#    </themes>
#    <totalprojects>
#     7
#    </totalprojects>
#    <url>
#     http://www.greenmap.org
#    </url>
#   </organization>
#   <progressreportlink>
#    https://www.globalgiving.org/projects/sustainable-living-with-green-maps/updates/
#   </progressreportlink>
#   <projectlink>
#    https://www.globalgiving.org/projects/sustainable-living-with-green-maps/
#   </projectlink>
#   <region>
#    North America
#   </region>
#   <remaining>
#    27232.00
#   </remaining>
#   <status>
#    funded
#   </status>
#   <summary>
#    Green Map Icons are a universal language for identifying environmental and cultural resources. Help local mapmakers foster sustainable living by updating this lexicon and a multilingual icon database.
#   </summary>
#   <themename>
#    Technology
#   </themename>
#   <title>
#    Icons for Mapping Community Sustainability
#   </title>
#   <type>
#    project
#   </type>
#  </project>
# </projects>

# %%
print(soup.hasnext)
"true" in soup.hasnext
print(soup.nextprojectid.contents)
# Out:
# <hasnext>true</hasnext>
# ['607']

# %%
projects = soup.find_all('project')

# %%
project1 = projects[0]
print(project1.theme.id.string)
# Out:
# children

# %%
# parse project
project_keys = [
    'action_tags',
    'issue_tags',
    'org_name',
    'org_url',
    'org_street',
    'org_city',
    'org_state',
    'org_zip',
    'org_logo',
    'project_name',
    'project_date',
    'project_img',
    'project_url',
    
]



def parse_project(project):

# %%
def print_all_results(response_soup):
    """get all project info
    """
    if response_soup.hasnext.string == "true":
        next_id = response_soup.nextprojectid.string
        projects = response_soup.find_all('project')
        for project in projects:
            if project.active.contents[0]=="true":
                print(project.title.contents, 
                      project.id.contents,
                      project.find_all('theme').name
                     )
        
        request_args.update({'nextProjectId': next_id})
        response = session.get(url, params=request_args)
        soup = BeautifulSoup(response.text, 'html.parser')
        return print_all_results(soup)
    
    else:
        projects = response_soup.find_all('project')
        for project in projects:
            print(project.title.contents, project.id.contents)
            
        return None
        
print_all_results(soup)
# Out:
# ------------------------------------------------
# NameError      Traceback (most recent call last)
# <ipython-input-1-655bd9313971> in <module>()
#      24         return None
#      25
# ---> 26 print_all_results(soup)
#      27
#
# NameError: name 'soup' is not defined

# %%
# API Class
country = "US"
base_url = "api.globalgiving.org/api/public"
end_point = "/projectservice/countries/{country_}/projects".format(country_=country)
request_args = {'api_key': keys['api_key']}

class GlobalGivingException(Exception):
    pass

class GlobalGivingAPI(object):
    def __init__(self, 
                 host, 
                 endpoint, 
                 params,
                 protocol="https", 
                 verify=False):
        self.protocol = protocol
        self.host = host
        self.endpoint = endpoint
        self.session = requests.session()
        self.session.verify = verify
        self.params = params
        
    
    @retry(stop_max_attempt_number=10, wait_fixed=500)
    def _get(self):
        url = self.protocol + '://' + self.host + self.endpoint

        try:
            response = self.session.get(url, params=self.params)
            if 'error_message' in response:
                raise GlobalGivingException(response['error_message'])
        except (requests.RequestException, ValueError) as e:
            print(url, kwargs)
            response = None

        return response
    
    def _gg_has_next(xml_soup):
        
    
    def _gg_xml_iter(self):
        """Iterate over api responses until no more hasNext tags.
        """
        has_next = True
        while self._gg_has_next():
            
    
    def get_gg_results(self):
        results = self._get().text
        results_soup = BeautifulSoup(results, 'html.parser')
        for result in results.text:
            yield result

# %%
gg_api = GlobalGivingAPI(base_url, end_point, request_args)

for i in gg_api.response_generator():
    print(i.text)
# Out:
# /Users/safyre/anaconda/envs/imwithdata/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-c8e9f2999e9e> in <module>()
#       2
#       3 for i in gg_api.response_generator():
# ----> 4     print(i.text)
#
# AttributeError: 'bytes' object has no attribute 'text'

# %% [markdown]
# # ElasticSearch
#
# https://elasticsearch-py.readthedocs.io/en/master/
